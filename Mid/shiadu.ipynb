# %%
import pandas as pd
import numpy as np
import yfinance as yf
import datetime
import requests
from scipy.stats import norm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import requests
import pandas as pd
from datetime import datetime

# 將民國日期轉為西元日期
def convert_tw_date(tw_date: str) -> str:
    y, m, d = map(int, tw_date.split('/'))
    return f"{y + 1911}-{m:02d}-{d:02d}"

# 抓取單月資料
def get_monthly_data(stock_no: str, year: int, month: int) -> pd.DataFrame:
    date = f"{year}{month:02d}01"
    url = "https://www.twse.com.tw/exchangeReport/STOCK_DAY"
    params = {
        "response": "json",
        "date": date,
        "stockNo": stock_no
    }
    headers = {
        "User-Agent": "Mozilla/5.0"
    }
    res = requests.get(url, params=params, headers=headers)
    data = res.json()
    if data["stat"] != "OK":
        return pd.DataFrame()
    
    df = pd.DataFrame(data["data"], columns=data["fields"])
    df["日期"] = df["日期"].apply(convert_tw_date)
    df["日期"] = pd.to_datetime(df["日期"])
    return df

# 抓取多月資料並合併
def get_range_data(stock_no: str, start: str, end: str) -> pd.DataFrame:
    start_date = datetime.strptime(start, "%Y-%m-%d")
    end_date = datetime.strptime(end, "%Y-%m-%d")

    all_data = pd.DataFrame()
    current = start_date

    while current <= end_date:
        df = get_monthly_data(stock_no, current.year, current.month)
        all_data = pd.concat([all_data, df], ignore_index=True)
        # 移到下個月
        if current.month == 12:
            current = datetime(current.year + 1, 1, 1)
        else:
            current = datetime(current.year, current.month + 1, 1)

    # 篩選目標範圍
    mask = (all_data["日期"] >= pd.to_datetime(start)) & (all_data["日期"] <= pd.to_datetime(end))
    return all_data.loc[mask].reset_index(drop=True)

# === 執行範例 ===
if __name__ == "__main__":
    stock_no = "2722"
    start_date = "2023-01-01"
    end_date = "2025-03-31"

    stock_df = get_range_data(stock_no, start_date, end_date)
    stock_df.rename(columns={
    '日期': 'post_time',
    '成交股數': 'volume',
    '成交金額': 'amount',
    '開盤價': 'open',
    '最高價': 'high',
    '最低價': 'low',
    '收盤價': 'close',
    '漲跌價差': 'change',
    '成交筆數': 'transaction'
}, inplace=True)
    stock_df.to_csv(f"{stock_no}_TWSE_{start_date}_to_{end_date}.csv", index=False, encoding="utf-8-sig")

    print(f"成功匯出 {len(stock_df)} 筆資料至 CSV！")
    print(stock_df.head())
# Out:
# 成功匯出 536 筆資料至 CSV！
#    post_time   volume     amount   open   high    low  close change  \
# 0 2023-01-03  107,253  3,512,864  33.25  33.25  32.50  32.80  -0.60
# 1 2023-01-04   95,435  3,110,800  33.00  33.35  32.25  32.40  -0.40
# 2 2023-01-05   87,294  2,845,907  32.45  33.00  32.20  32.25  -0.15
# 3 2023-01-06   60,015  1,927,481  32.25  32.45  32.00  32.10  -0.15
# 4 2023-01-09   58,308  1,875,796  32.35  32.35  32.05  32.15  +0.05
#
#   transaction
# 0         118
# 1         103
# 2         104
# 3          57
# 4          87

# %%
# stock_df.rename(columns={'日期': 'post_time'}, inplace=True)
# stock_df.rename(columns={'成交股數': 'volume'}, inplace=True)
# stock_df.rename(columns={'成交金額': 'amount'}, inplace=True)
# stock_df.rename(columns={'開盤價': 'open'}, inplace=True)
# stock_df.rename(columns={'最高價': 'high'}, inplace=True)
# stock_df.rename(columns={'最低價': 'low'}, inplace=True)
# stock_df.rename(columns={'收盤價': 'close'}, inplace=True)
# stock_df.rename(columns={'漲跌價差': 'change'}, inplace=True)
# stock_df.rename(columns={'成交筆數': 'transaction'}, inplace=True)

# %%
stock_df
# Out:
#      post_time   volume     amount   open   high    low  close change  \
# 0   2023-01-03  107,253  3,512,864  33.25  33.25  32.50  32.80  -0.60
# 1   2023-01-04   95,435  3,110,800  33.00  33.35  32.25  32.40  -0.40
# 2   2023-01-05   87,294  2,845,907  32.45  33.00  32.20  32.25  -0.15
# 3   2023-01-06   60,015  1,927,481  32.25  32.45  32.00  32.10  -0.15
# 4   2023-01-09   58,308  1,875,796  32.35  32.35  32.05  32.15  +0.05
# ..         ...      ...        ...    ...    ...    ...    ...    ...
# 531 2025-03-25   80,281  2,509,545  31.40  31.60  31.00  31.00  -0.55
# 532 2025-03-26   67,273  2,121,353  32.00  32.00  31.40  31.70  +0.70
# 533 2025-03-27   40,552  1,270,052  31.50  31.50  31.15  31.20  -0.50
# 534 2025-03-28  141,260  4,306,202  30.85  30.85  30.20  30.35  -0.85
# 535 2025-03-31  188,171  5,503,677  30.20  30.20  28.80  29.10  -1.25
#
#     transaction
# 0           118
# 1           103
# 2           104
# 3            57
# 4            87
# ..          ...
# 531          57
# 532          48
# 533          43
# 534         109
# 535         183
#
# [536 rows x 9 columns]

# %%
stock_df['close'] = stock_df['close'].astype(float)

# %%
stock_df.loc[0, 'close']
# Out:
# np.float64(32.8)

# %%
for i in range(1, len(stock_df)):
    stock_df.at[i, "change"] = stock_df.loc[i, "close"] - stock_df.loc[i-1, "close"]
    stock_df.at[i, "return"] = stock_df.at[i, "change"] / stock_df.loc[i-1, "close"]
stock_df["change"] = stock_df["change"].astype(float)
stock_df["return"] = stock_df["return"].astype(float)
stock_df
# Out:
#      post_time   volume     amount   open   high    low  close  change  \
# 0   2023-01-03  107,253  3,512,864  33.25  33.25  32.50  32.80   -0.60
# 1   2023-01-04   95,435  3,110,800  33.00  33.35  32.25  32.40   -0.40
# 2   2023-01-05   87,294  2,845,907  32.45  33.00  32.20  32.25   -0.15
# 3   2023-01-06   60,015  1,927,481  32.25  32.45  32.00  32.10   -0.15
# 4   2023-01-09   58,308  1,875,796  32.35  32.35  32.05  32.15    0.05
# ..         ...      ...        ...    ...    ...    ...    ...     ...
# 531 2025-03-25   80,281  2,509,545  31.40  31.60  31.00  31.00   -0.55
# 532 2025-03-26   67,273  2,121,353  32.00  32.00  31.40  31.70    0.70
# 533 2025-03-27   40,552  1,270,052  31.50  31.50  31.15  31.20   -0.50
# 534 2025-03-28  141,260  4,306,202  30.85  30.85  30.20  30.35   -0.85
# 535 2025-03-31  188,171  5,503,677  30.20  30.20  28.80  29.10   -1.25
#
#     transaction    return
# 0           118       NaN
# 1           103 -0.012195
# 2           104 -0.004630
# 3            57 -0.004651
# 4            87  0.001558
# ..          ...       ...
# 531          57 -0.017433
# 532          48  0.022581
# 533          43 -0.015773
# 534         109 -0.027244
# 535         183 -0.041186
#
# [536 rows x 10 columns]

# %%
stock_df['return'].fillna(0, inplace=True)
# Out:
# /var/folders/yt/6_xzvtrx40vg93_r3y7kdjtc0000gn/T/ipykernel_23479/925586977.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   stock_df['return'].fillna(0, inplace=True)

# %%
stock_df_mean = stock_df["return"].mean()
stock_df_std = stock_df["return"].std()

alpha = 0.05
z_score = norm.ppf(1 - alpha/2)
upper_bound = stock_df_mean + z_score*(stock_df_std / (len(stock_df['return'])**0.5))
lower_bound = stock_df_mean - z_score*(stock_df_std / (len(stock_df['return'])**0.5))
confidence_interval = (lower_bound, upper_bound)
confidence_interval

stock_df["BullBear"] = stock_df["return"].apply(lambda x: -1 if x<lower_bound else(1 if x>upper_bound else 0))

print(stock_df[["return", "BullBear"]].head(10))

stock_df['post_time'] = pd.to_datetime(stock_df['post_time'])
stock_df['previous_date'] = stock_df['post_time'].shift(1)
stock_df['previous_date_2'] = stock_df['post_time'] - pd.Timedelta(days = 1)
stock_df
# Out:
#      return  BullBear
# 0  0.000000         0
# 1 -0.012195        -1
# 2 -0.004630        -1
# 3 -0.004651        -1
# 4  0.001558         0
# 5  0.007776         1
# 6  0.003086         1
# 7  0.000000         0
# 8  0.003077         1
# 9 -0.001534         0
#      post_time   volume     amount   open   high    low  close  change  \
# 0   2023-01-03  107,253  3,512,864  33.25  33.25  32.50  32.80   -0.60
# 1   2023-01-04   95,435  3,110,800  33.00  33.35  32.25  32.40   -0.40
# 2   2023-01-05   87,294  2,845,907  32.45  33.00  32.20  32.25   -0.15
# 3   2023-01-06   60,015  1,927,481  32.25  32.45  32.00  32.10   -0.15
# 4   2023-01-09   58,308  1,875,796  32.35  32.35  32.05  32.15    0.05
# ..         ...      ...        ...    ...    ...    ...    ...     ...
# 531 2025-03-25   80,281  2,509,545  31.40  31.60  31.00  31.00   -0.55
# 532 2025-03-26   67,273  2,121,353  32.00  32.00  31.40  31.70    0.70
# 533 2025-03-27   40,552  1,270,052  31.50  31.50  31.15  31.20   -0.50
# 534 2025-03-28  141,260  4,306,202  30.85  30.85  30.20  30.35   -0.85
# 535 2025-03-31  188,171  5,503,677  30.20  30.20  28.80  29.10   -1.25
#
#     transaction    return  BullBear previous_date previous_date_2
# 0           118  0.000000         0           NaT      2023-01-02
# 1           103 -0.012195        -1    2023-01-03      2023-01-03
# 2           104 -0.004630        -1    2023-01-04      2023-01-04
# 3            57 -0.004651        -1    2023-01-05      2023-01-05
# 4            87  0.001558         0    2023-01-06      2023-01-08
# ..          ...       ...       ...           ...             ...
# 531          57 -0.017433        -1    2025-03-24      2025-03-24
# 532          48  0.022581         1    2025-03-25      2025-03-25
# 533          43 -0.015773        -1    2025-03-26      2025-03-26
# 534         109 -0.027244        -1    2025-03-27      2025-03-27
# 535         183 -0.041186        -1    2025-03-28      2025-03-30
#
# [536 rows x 13 columns]

# %%
Bull_data = stock_df[stock_df['BullBear'] == 1]
Bear_data = stock_df[stock_df['BullBear'] == -1]
Bull_data = Bull_data[['post_time', 'previous_date', 'previous_date_2', 'BullBear', 'return']]
Bear_data = Bear_data[['post_time', 'previous_date', 'previous_date_2', 'BullBear', 'return']]

# %%
Bull_data
# Out:
#      post_time previous_date previous_date_2  BullBear    return
# 5   2023-01-10    2023-01-09      2023-01-09         1  0.007776
# 6   2023-01-11    2023-01-10      2023-01-10         1  0.003086
# 8   2023-01-13    2023-01-12      2023-01-12         1  0.003077
# 10  2023-01-17    2023-01-16      2023-01-16         1  0.003072
# 12  2023-01-31    2023-01-30      2023-01-30         1  0.012289
# ..         ...           ...             ...       ...       ...
# 508 2025-02-19    2025-02-18      2025-02-18         1  0.005714
# 517 2025-03-05    2025-03-04      2025-03-04         1  0.013216
# 526 2025-03-18    2025-03-17      2025-03-17         1  0.011290
# 528 2025-03-20    2025-03-19      2025-03-19         1  0.025600
# 532 2025-03-26    2025-03-25      2025-03-25         1  0.022581
#
# [201 rows x 5 columns]

# %%
plt.figure(figsize=(15, 5))
sns.histplot(data = stock_df, x = 'return', color= '#FF8000', kde=False, bins=10)
plt.axvline(stock_df_mean, color='red', linestyle='dashed', linewidth=1.5, label=f'Mean: {round(stock_df_mean, 5)}')
plt.axvline(lower_bound, color='green', linestyle='dashed', linewidth=1.5, label=f'95% CI Lower: {round(lower_bound, 5)}')
plt.axvline(upper_bound, color='blue', linestyle='dashed', linewidth=1.5, label=f'95% CI Upper: {round(upper_bound, 5)}')
plt.title('Distribution of Daily Returns')
plt.ylabel('Frequency')
plt.legend()

# %%
Bull_data.to_csv(f"{stock_no}_Bull_data.csv", index=False, encoding="utf-8")
Bear_data.to_csv(f"{stock_no}_Bear_data.csv", index=False, encoding="utf-8")

# %%
# yfinance沒有夏都
# ticker = '2722.TW'

# shiadu = yf.download(ticker, start='2023-01-01', end='2025-03-31')

# print(shiadu.head())

# %%
news = pd.read_csv('bda2025_202301-202503_內容數據_新聞.csv')
dcard1 = pd.read_csv('bda2025_202301-202503_討論數據_dcard_1.csv')
dcard2 = pd.read_csv('bda2025_202301-202503_討論數據_dcard_2.csv')
mobile01 = pd.read_csv('bda2025_202301-202503_討論數據_Mobile01.csv')
ptt = pd.read_csv('bda2025_202301-202503_討論數據_PTT.csv')
df = pd.concat([news, dcard1, dcard2, mobile01, ptt],axis=0).reset_index(drop=True)
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 news = pd.read_csv('bda2025_202301-202503_內容數據_新聞.csv')
#       2 dcard1 = pd.read_csv('bda2025_202301-202503_討論數據_dcard_1.csv')
#       3 dcard2 = pd.read_csv('bda2025_202301-202503_討論數據_dcard_2.csv')
#
# File /opt/anaconda3/envs/Manufacturing-Data-Science/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/envs/Manufacturing-Data-Science/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /opt/anaconda3/envs/Manufacturing-Data-Science/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /opt/anaconda3/envs/Manufacturing-Data-Science/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /opt/anaconda3/envs/Manufacturing-Data-Science/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bda2025_202301-202503_內容數據_新聞.csv'

# %%
df.shape
# Out:
# (661994, 10)

# %%
df_filtered = df[(df['title'].str.contains("夏都")) | (df['content'].str.contains("夏都"))]
df_filtered.head(10)
# Out:
#                            id p_type   s_name s_area_name  \
# 398   1673924326710_YahooNews   news  Yahoo新聞        股市匯市
# 958   1675924003375_YahooNews   news  Yahoo新聞        股市匯市
# 1122  1676442785533_YahooNews   news  Yahoo新聞        股市匯市
# 1260  1676879134931_YahooNews   news  Yahoo新聞        股市匯市
# 1315  1677035900334_YahooNews   news  Yahoo新聞        股市匯市
# 1324  1677045659659_YahooNews   news  Yahoo新聞        股市匯市
# 1327  1677051627941_YahooNews   news  Yahoo新聞        股市匯市
# 1360  1677121476845_YahooNews   news  Yahoo新聞        股市匯市
# 1361  1677121476696_YahooNews   news  Yahoo新聞        股市匯市
# 1542  1677722877669_YahooNews   news  Yahoo新聞        股市匯市
#
#                 post_time                                     title  \
# 398   2023-01-17 10:05:44            虎年封關電子熄火 航運觀光撐場 價跌量縮14900點震盪整理
# 958   2023-02-09 14:19:37  春天來了...王品、新天地營收年增兩位數 雄獅年增近6倍、現增申購抽中賺2.8萬
# 1122  2023-02-15 13:41:10           〈台股盤後〉台積重挫 大跌221點收15432點 摜破10日線
# 1260  2023-02-20 14:58:33          台股反彈站回15500點 投信連3買 三大法人賣超19.76億元
# 1315  2023-02-22 10:23:50             〈台股盤中〉普丁搗亂電金臉綠 大盤失守月線跌破15400點
# 1324  2023-02-22 13:10:07                  〈焦點股〉觀光族群聯袂亮燈 漲停家數占大盤近4成
# 1327  2023-02-22 15:10:13                 美股重挫、科技股領跌 台股早盤跌217點｜#鏡新聞
# 1360  2023-02-23 10:55:23                    台積電回穩運輸觀光強攻 台股盤中漲逾200點
# 1361  2023-02-23 10:59:09                       台股盤中漲逾200點 台積電大漲14元
# 1542  2023-03-02 09:19:18      盤中速報 - 觀光類指數類股表現強勁，漲幅3.9%，總成交額19.90億
#
#                              author  \
# 398                     鉅亨網記者郭幸宜 台北
# 958                             葉佳華
# 1122                    鉅亨網記者沈筱禎 台北
# 1260                        鉅亨網新聞中心
# 1315                    鉅亨網記者郭幸宜 台北
# 1324                    鉅亨網記者王莞甯 台北
# 1327                            NaN
# 1360  The Central News Agency 中央通訊社
# 1361                            NaN
# 1542                        鉅亨網新聞中心
#
#                                                 content  \
# 398   台股今 (17) 日進行虎年封關交易，大盤多空勢力在平盤附近拉扯，權王台積電 (2330-T...
# 958   受惠政府解除組團禁令，加上春節十天連假效應，觀光需求活絡帶動旅行社1月營收增長。（攝影／葉佳...
# 1122  股神巴菲特旗下投資公司波克夏重砍台積電 ADR，減持幅度高達 86%，台積電現貨今 (15)...
# 1260  台股今 (20) 日開低走高，隨著電子權值股止跌回穩，金融股強勢走揚，加上觀光百貨、車電等中...
# 1315  美股四大指數重挫，台股今 (22) 日也跟著臉綠，權王台積電 (2330-TW) 帶頭領跌，...
# 1324  隨著美債殖利率飆升，美股重挫，台股加權指數今 (22) 日大跌超過百點，尤其中高價電子股遭摜...
# 1327  台股今天（22日）受到美股4大指數週二全面下挫影響，跟進走跌，早盤最低下探15345點、重跌...
# 1360  （中央社記者韓婷婷台北23日電）輝達（Nvidia）財報優於預期盤後大漲逾8%，帶動美股電子...
# 1361  輝達（Nvidia）財報優於預期盤後大漲逾8%，帶動美股電子盤走揚，台股在台積電回穩反攻，搭...
# 1542  台股今日觀光事業類股表現強勁，02日09:19相關指數上漲3.9%，總成交額19.90億元，...
#
#                                                page_url content_type
# 398   https://tw.news.yahoo.com/%E8%99%8E%E5%B9%B4%E...          NaN
# 958   https://tw.news.yahoo.com/%E6%98%A5%E5%A4%A9%E...          NaN
# 1122  https://tw.news.yahoo.com/%E5%8F%B0%E8%82%A1%E...          NaN
# 1260  https://tw.news.yahoo.com/%E5%8F%B0%E8%82%A1%E...          NaN
# 1315  https://tw.news.yahoo.com/%E5%8F%B0%E8%82%A1%E...          NaN
# 1324  https://tw.news.yahoo.com/%E7%84%A6%E9%BB%9E%E...          NaN
# 1327  https://tw.news.yahoo.com/%E7%BE%8E%E8%82%A1%E...          NaN
# 1360  https://tw.news.yahoo.com/%E5%8F%B0%E7%A9%8D%E...          NaN
# 1361  https://tw.news.yahoo.com/%E5%8F%B0%E8%82%A1%E...          NaN
# 1542  https://tw.news.yahoo.com/%E7%9B%A4%E4%B8%AD%E...          NaN

# %%
df_filtered = df_filtered[['post_time','title', 'content']]
df_filtered.shape
# Out:
# (683, 3)

# %%
df_filtered['post_time'] = pd.to_datetime(df_filtered['post_time']).dt.date
df_filtered.head(10)
# Out:
#        post_time                                     title  \
# 398   2023-01-17            虎年封關電子熄火 航運觀光撐場 價跌量縮14900點震盪整理
# 958   2023-02-09  春天來了...王品、新天地營收年增兩位數 雄獅年增近6倍、現增申購抽中賺2.8萬
# 1122  2023-02-15           〈台股盤後〉台積重挫 大跌221點收15432點 摜破10日線
# 1260  2023-02-20          台股反彈站回15500點 投信連3買 三大法人賣超19.76億元
# 1315  2023-02-22             〈台股盤中〉普丁搗亂電金臉綠 大盤失守月線跌破15400點
# 1324  2023-02-22                  〈焦點股〉觀光族群聯袂亮燈 漲停家數占大盤近4成
# 1327  2023-02-22                 美股重挫、科技股領跌 台股早盤跌217點｜#鏡新聞
# 1360  2023-02-23                    台積電回穩運輸觀光強攻 台股盤中漲逾200點
# 1361  2023-02-23                       台股盤中漲逾200點 台積電大漲14元
# 1542  2023-03-02      盤中速報 - 觀光類指數類股表現強勁，漲幅3.9%，總成交額19.90億
#
#                                                 content
# 398   台股今 (17) 日進行虎年封關交易，大盤多空勢力在平盤附近拉扯，權王台積電 (2330-T...
# 958   受惠政府解除組團禁令，加上春節十天連假效應，觀光需求活絡帶動旅行社1月營收增長。（攝影／葉佳...
# 1122  股神巴菲特旗下投資公司波克夏重砍台積電 ADR，減持幅度高達 86%，台積電現貨今 (15)...
# 1260  台股今 (20) 日開低走高，隨著電子權值股止跌回穩，金融股強勢走揚，加上觀光百貨、車電等中...
# 1315  美股四大指數重挫，台股今 (22) 日也跟著臉綠，權王台積電 (2330-TW) 帶頭領跌，...
# 1324  隨著美債殖利率飆升，美股重挫，台股加權指數今 (22) 日大跌超過百點，尤其中高價電子股遭摜...
# 1327  台股今天（22日）受到美股4大指數週二全面下挫影響，跟進走跌，早盤最低下探15345點、重跌...
# 1360  （中央社記者韓婷婷台北23日電）輝達（Nvidia）財報優於預期盤後大漲逾8%，帶動美股電子...
# 1361  輝達（Nvidia）財報優於預期盤後大漲逾8%，帶動美股電子盤走揚，台股在台積電回穩反攻，搭...
# 1542  台股今日觀光事業類股表現強勁，02日09:19相關指數上漲3.9%，總成交額19.90億元，...

# %%
df_filtered
# Out:
#          post_time                                     title  \
# 398     2023-01-17            虎年封關電子熄火 航運觀光撐場 價跌量縮14900點震盪整理
# 958     2023-02-09  春天來了...王品、新天地營收年增兩位數 雄獅年增近6倍、現增申購抽中賺2.8萬
# 1122    2023-02-15           〈台股盤後〉台積重挫 大跌221點收15432點 摜破10日線
# 1260    2023-02-20          台股反彈站回15500點 投信連3買 三大法人賣超19.76億元
# 1315    2023-02-22             〈台股盤中〉普丁搗亂電金臉綠 大盤失守月線跌破15400點
# ...            ...                                       ...
# 654027  2024-11-20                       [創作] Baby Shark(夏都)
# 657595  2025-01-09                  [新聞] 慘！墾丁驚傳3家飯店將熄燈 觀光業再受
# 658099  2025-01-14                         [情報] 2722 夏都12月自結
# 658359  2025-01-17                      [閒聊] 2025/01/17 盤後閒聊
# 661326  2025-02-20                    [新聞] 台積電被超車了！市值跌出全球前10
#
#                                                   content
# 398     台股今 (17) 日進行虎年封關交易，大盤多空勢力在平盤附近拉扯，權王台積電 (2330-T...
# 958     受惠政府解除組團禁令，加上春節十天連假效應，觀光需求活絡帶動旅行社1月營收增長。（攝影／葉佳...
# 1122    股神巴菲特旗下投資公司波克夏重砍台積電 ADR，減持幅度高達 86%，台積電現貨今 (15)...
# 1260    台股今 (20) 日開低走高，隨著電子權值股止跌回穩，金融股強勢走揚，加上觀光百貨、車電等中...
# 1315    美股四大指數重挫，台股今 (22) 日也跟著臉綠，權王台積電 (2330-TW) 帶頭領跌，...
# ...                                                   ...
# 654027  https://youtu.be/XqZsoesa55w  突然有一咪咪靈感(?  ====...
# 657595  原文標題：  慘！墾丁驚傳3家飯店將熄燈 觀光業再受重擊  原文連結：  https://n...
# 658099  標題：  2722 夏都12月自結  來源：  公開資訊觀測站  網址：  https://...
# 658359  台　股　23148.08　▲122.98 (+0.53%)　3203.17億 台指02　23...
# 661326  原文標題：  台積電被超車了！市值跌出全球前10  原文連結：  https://ec.lt...
#
# [683 rows x 3 columns]

# %%
df_filtered.to_csv(f"{stock_no}_news.csv", index=False, encoding="utf-8")

# %%
import csv
import monpa
from monpa import utils
# Out:
# +---------------------------------------------------------------------+
#   Welcome to MONPA: Multi-Objective NER POS Annotator for Chinese
# +---------------------------------------------------------------------+
# 已找到 model檔。Found model file.

# %%
#篩選出顯示牛市或熊市的新聞
df_filtered['post_time'] = pd.to_datetime(df_filtered['post_time']).dt.date
Bull_data['previous_date_2'] = pd.to_datetime(Bull_data['previous_date_2']).dt.date
Bear_data['previous_date_2'] = pd.to_datetime(Bear_data['previous_date_2']).dt.date


Bull_news = df_filtered[df_filtered['post_time'].isin(Bull_data['previous_date_2'])]
Bear_news = df_filtered[df_filtered['post_time'].isin(Bear_data['previous_date_2'])]
Bull_news['BullBear'] = 1
Bear_news['BullBear'] = -1
Bull_news
# Out:
# /var/folders/dp/v8nwqctd0rqfmk1cclf4q0w40000gn/T/ipykernel_45383/2288370449.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Bull_news['BullBear'] = 1
# /var/folders/dp/v8nwqctd0rqfmk1cclf4q0w40000gn/T/ipykernel_45383/2288370449.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Bear_news['BullBear'] = -1
#          post_time                            title  \
# 1122    2023-02-15  〈台股盤後〉台積重挫 大跌221點收15432點 摜破10日線
# 1315    2023-02-22    〈台股盤中〉普丁搗亂電金臉綠 大盤失守月線跌破15400點
# 1324    2023-02-22         〈焦點股〉觀光族群聯袂亮燈 漲停家數占大盤近4成
# 1327    2023-02-22        美股重挫、科技股領跌 台股早盤跌217點｜#鏡新聞
# 1360    2023-02-23           台積電回穩運輸觀光強攻 台股盤中漲逾200點
# ...            ...                              ...
# 615959  2023-07-24                [情報] 00733成分股審核結果
# 632288  2024-03-31             [心得] 2024年Q1 台股跌幅排行榜
# 637283  2024-05-28        [新聞] 5月底將公布兩岸旅遊開放利多 觀光股先買
# 642871  2024-07-22       [情報] 2722 夏都 辦理現金增資 暫定價35元
# 642874  2024-07-22       [情報] 2722 夏都 投資設立子公司夏都地產開發
#
#                                                   content  BullBear
# 1122    股神巴菲特旗下投資公司波克夏重砍台積電 ADR，減持幅度高達 86%，台積電現貨今 (15)...         1
# 1315    美股四大指數重挫，台股今 (22) 日也跟著臉綠，權王台積電 (2330-TW) 帶頭領跌，...         1
# 1324    隨著美債殖利率飆升，美股重挫，台股加權指數今 (22) 日大跌超過百點，尤其中高價電子股遭摜...         1
# 1327    台股今天（22日）受到美股4大指數週二全面下挫影響，跟進走跌，早盤最低下探15345點、重跌...         1
# 1360    （中央社記者韓婷婷台北23日電）輝達（Nvidia）財報優於預期盤後大漲逾8%，帶動美股電子...         1
# ...                                                   ...       ...
# 615959  1. 標題：「臺灣指數公司中小型 A 級動能 50 指數」第三次成分股審核結果  2. 來源...         1
# 632288  代號  公司  市場     跌幅(%)  23Q4    24Q1            ...         1
# 637283  原文標題：  5月底將公布兩岸旅遊開放利多 觀光股先買先贏「這六檔」率先漲停  原文連結：h...         1
# 642871  1. 標題：公告本公司董事會通過辦理現金增資發行普通股  2. 來源：公開資訊觀測站  3....         1
# 642874  標題：公告本公司董事會通過投資設立子公司  來源：公開資訊觀測站  網址： https://...         1
#
# [269 rows x 4 columns]

# %%
# Convert post_time in df_filtered to datetime
df_filtered['post_time'] = pd.to_datetime(df_filtered['post_time'])

# Convert previous_date_2 in stock_df to datetime
stock_df['previous_date_2'] = pd.to_datetime(stock_df['previous_date_2'])

# Now prepare stock_return and merge
stock_return = stock_df[['previous_date_2', 'return']].rename(columns={
    'previous_date_2': 'post_time',
    'return': 'Return'
})

# Drop Return if it already exists
df_filtered = df_filtered.drop(columns='Return', errors='ignore')

# Merge safely
df_joined = df_filtered.merge(stock_return, on='post_time', how='left')

# Fill NaN with 0
df_joined['Return'] = df_joined['Return'].fillna(0)
df_joined
# Out:
#      post_time                                     title  \
# 0   2023-01-17            虎年封關電子熄火 航運觀光撐場 價跌量縮14900點震盪整理
# 1   2023-02-09  春天來了...王品、新天地營收年增兩位數 雄獅年增近6倍、現增申購抽中賺2.8萬
# 2   2023-02-15           〈台股盤後〉台積重挫 大跌221點收15432點 摜破10日線
# 3   2023-02-20          台股反彈站回15500點 投信連3買 三大法人賣超19.76億元
# 4   2023-02-22             〈台股盤中〉普丁搗亂電金臉綠 大盤失守月線跌破15400點
# ..         ...                                       ...
# 678 2024-11-20                       [創作] Baby Shark(夏都)
# 679 2025-01-09                  [新聞] 慘！墾丁驚傳3家飯店將熄燈 觀光業再受
# 680 2025-01-14                         [情報] 2722 夏都12月自結
# 681 2025-01-17                      [閒聊] 2025/01/17 盤後閒聊
# 682 2025-02-20                    [新聞] 台積電被超車了！市值跌出全球前10
#
#                                                content BullBear    Return
# 0    台股今 (17) 日進行虎年封關交易，大盤多空勢力在平盤附近拉扯，權王台積電 (2330-T...    Equal  0.000000
# 1    受惠政府解除組團禁令，加上春節十天連假效應，觀光需求活絡帶動旅行社1月營收增長。（攝影／葉佳...     Down -0.003021
# 2    股神巴菲特旗下投資公司波克夏重砍台積電 ADR，減持幅度高達 86%，台積電現貨今 (15)...       Up  0.007123
# 3    台股今 (20) 日開低走高，隨著電子權值股止跌回穩，金融股強勢走揚，加上觀光百貨、車電等中...     Down -0.036649
# 4    美股四大指數重挫，台股今 (22) 日也跟著臉綠，權王台積電 (2330-TW) 帶頭領跌，...       Up  0.098888
# ..                                                 ...      ...       ...
# 678  https://youtu.be/XqZsoesa55w  突然有一咪咪靈感(?  ====...    Equal  0.001299
# 679  原文標題：  慘！墾丁驚傳3家飯店將熄燈 觀光業再受重擊  原文連結：  https://n...     Down -0.023697
# 680  標題：  2722 夏都12月自結  來源：  公開資訊觀測站  網址：  https://...    Equal  0.000000
# 681  台　股　23148.08　▲122.98 (+0.53%)　3203.17億 台指02　23...    Equal  0.000000
# 682  原文標題：  台積電被超車了！市值跌出全球前10  原文連結：  https://ec.lt...    Equal  0.002857
#
# [683 rows x 5 columns]

# %%
for i in range(len(df_joined)):
    if df_joined.loc[i, 'Return'] > 0:
        df_joined.at[i, 'BullBear'] = 'Up'
    elif df_joined.loc[i, 'Return'] < 0:
        df_joined.at[i, 'BullBear'] = 'Down'
    else:
        df_joined.at[i, 'BullBear'] = 'Equal'

df_joined
# Out:
#      post_time                                     title  \
# 0   2023-01-17            虎年封關電子熄火 航運觀光撐場 價跌量縮14900點震盪整理
# 1   2023-02-09  春天來了...王品、新天地營收年增兩位數 雄獅年增近6倍、現增申購抽中賺2.8萬
# 2   2023-02-15           〈台股盤後〉台積重挫 大跌221點收15432點 摜破10日線
# 3   2023-02-20          台股反彈站回15500點 投信連3買 三大法人賣超19.76億元
# 4   2023-02-22             〈台股盤中〉普丁搗亂電金臉綠 大盤失守月線跌破15400點
# ..         ...                                       ...
# 678 2024-11-20                       [創作] Baby Shark(夏都)
# 679 2025-01-09                  [新聞] 慘！墾丁驚傳3家飯店將熄燈 觀光業再受
# 680 2025-01-14                         [情報] 2722 夏都12月自結
# 681 2025-01-17                      [閒聊] 2025/01/17 盤後閒聊
# 682 2025-02-20                    [新聞] 台積電被超車了！市值跌出全球前10
#
#                                                content BullBear    Return
# 0    台股今 (17) 日進行虎年封關交易，大盤多空勢力在平盤附近拉扯，權王台積電 (2330-T...    Equal  0.000000
# 1    受惠政府解除組團禁令，加上春節十天連假效應，觀光需求活絡帶動旅行社1月營收增長。（攝影／葉佳...     Down -0.003021
# 2    股神巴菲特旗下投資公司波克夏重砍台積電 ADR，減持幅度高達 86%，台積電現貨今 (15)...       Up  0.007123
# 3    台股今 (20) 日開低走高，隨著電子權值股止跌回穩，金融股強勢走揚，加上觀光百貨、車電等中...     Down -0.036649
# 4    美股四大指數重挫，台股今 (22) 日也跟著臉綠，權王台積電 (2330-TW) 帶頭領跌，...       Up  0.098888
# ..                                                 ...      ...       ...
# 678  https://youtu.be/XqZsoesa55w  突然有一咪咪靈感(?  ====...       Up  0.001299
# 679  原文標題：  慘！墾丁驚傳3家飯店將熄燈 觀光業再受重擊  原文連結：  https://n...     Down -0.023697
# 680  標題：  2722 夏都12月自結  來源：  公開資訊觀測站  網址：  https://...    Equal  0.000000
# 681  台　股　23148.08　▲122.98 (+0.53%)　3203.17億 台指02　23...    Equal  0.000000
# 682  原文標題：  台積電被超車了！市值跌出全球前10  原文連結：  https://ec.lt...       Up  0.002857
#
# [683 rows x 5 columns]

# %%
df_joined.to_csv(f"{stock_no}_news_with_bullbear.csv", index=False, encoding="utf-8")

# %%
Bear_news
# Out:
#          post_time                                     title  \
# 958     2023-02-09  春天來了...王品、新天地營收年增兩位數 雄獅年增近6倍、現增申購抽中賺2.8萬
# 1260    2023-02-20          台股反彈站回15500點 投信連3買 三大法人賣超19.76億元
# 1697    2023-03-07                         電金傳點火！台股成功站15800點
# 1924    2023-03-14                    資金提款走人 電金傳氣虛 台股大跌逾170點
# 2471    2023-03-29                〈台股盤中〉漲幅收斂收斂 觀光族群、散熱雙雄逆勢強漲
# ...            ...                                       ...
# 646205  2024-08-19                [新聞] 10大旅館營收「亮紅字」衰退16%　學者：
# 646232  2024-08-19                 [新聞] 台人更愛出國！花蓮知名飯店「營收跳水72
# 648536  2024-09-12                  [新聞] 【退休只買一支股1】交給股神巴菲特操盤
# 652876  2024-11-07                     [情報] 2722 夏都 申購抽籤日程資訊
# 657595  2025-01-09                  [新聞] 慘！墾丁驚傳3家飯店將熄燈 觀光業再受
#
#                                                   content  BullBear
# 958     受惠政府解除組團禁令，加上春節十天連假效應，觀光需求活絡帶動旅行社1月營收增長。（攝影／葉佳...        -1
# 1260    台股今 (20) 日開低走高，隨著電子權值股止跌回穩，金融股強勢走揚，加上觀光百貨、車電等中...        -1
# 1697    [NOWnews今日新聞]全球市場等待美國聯準會（Fed）主席鮑爾發表談話以及就業數據發布，...        -1
# 1924    矽谷銀行 (SVB) 倒閉觸發市場恐慌情緒，美股僅那指上漲，其餘三大指數全數下跌，台股今 (...        -1
# 2471    儘管美股四大指數 28 日收跌，台股今 (29) 日經歷連兩日跌勢後反彈走強，早盤權值股紛紛...        -1
# ...                                                   ...       ...
# 646205  原文標題：10大旅館營收「亮紅字」衰退16%　學者：年底恐有倒閉潮   原文連結：https...        -1
# 646232   作者: buzu () 看板: Gossiping 標題: [新聞] 台人更愛出國！花蓮知...        -1
# 648536  原文標題：  【退休只買一支股1】交給股神巴菲特操盤　國小老師靠1檔股票輕鬆退休  原文連結...        -1
# 652876  1. 標題：2722 夏都 申購抽籤日程資訊  2. 來源：TWSE 公開申購公告-抽籤日程...        -1
# 657595  原文標題：  慘！墾丁驚傳3家飯店將熄燈 觀光業再受重擊  原文連結：  https://n...        -1
#
# [220 rows x 4 columns]

# %%
print(Bull_news.shape)
print(Bear_news.shape)
# Out:
# (269, 4)
# (220, 4)

# %%
Bull_news.to_csv(f"{stock_no}_Bull_news.csv", index=False, encoding="utf-8")
Bear_news.to_csv(f"{stock_no}_Bear_news.csv", index=False, encoding="utf-8")
