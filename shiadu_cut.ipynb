# %%
import csv
import monpa
from monpa import utils
from collections import Counter

# %%
tf_counter_bull = Counter()
df_counter_bull = Counter()

f = open('2722_Bull_news.csv', newline='', encoding='utf-8')
rows = csv.reader(f, delimiter=',')
i = 0
for row in rows:
    # print(row[1], row[2])
    i = i + 1
    if i > 1:
        query = row[1]+' ' + row[2]
        df_temp = Counter()
        sentence_list = utils.short_sentence(query)
        for item in sentence_list:
            word_cut = monpa.cut(item)
            for term in word_cut:
                term = term.strip()
                if (len(term) > 1):
                    tf_counter_bull[term] += 1
                    if (df_temp[term] == 0):
                        df_temp[term] = 1
        df_counter_bull += df_temp

f.close()

# %%
df_counter_bull
# Out:
# Counter({'夏都': 246,
#          '台股': 177,
#          '指數': 174,
#          '2722': 172,
#          '觀光': 160,
#          '漲停': 151,
#          '寒舍': 137,
#          '表現': 134,
#          '台積電': 131,
#          '股價': 130,
#          '台北': 125,
#          '漲幅': 123,
#          '族群': 121,
#          '市場': 116,
#          '聯發科': 114,
#          '上漲': 113,
#          '雲品': 108,
#          '震盪': 106,
#          '類股': 102,
#          '加權': 101,
#          '美股': 101,
#          '下跌': 100,
#          '今日': 98,
#          '法人': 96,
#          '持續': 93,
#          'KY': 93,
#          '鳳凰': 91,
#          '電子': 90,
#          '外資': 89,
#          'AI': 88,
#          '帶動': 86,
#          '2739': 86,
#          '2330': 85,
#          '股市': 84,
#          '大漲': 84,
#          '強勢': 82,
#          '加上': 79,
#          '記者': 79,
#          '表示': 79,
#          '10': 78,
#          '終場': 78,
#          '鴻海': 76,
#          '觀光股': 74,
#          '美國': 74,
#          '時報': 73,
#          '今年': 72,
#          '跌幅': 71,
#          '資金': 71,
#          '2454': 71,
#          '營收': 70,
#          '其中': 69,
#          '新高': 68,
#          '成交量': 67,
#          '大盤': 67,
#          '預期': 66,
#          '相關': 66,
#          '台灣': 66,
#          '獲利': 65,
#          '走高': 65,
#          '富野': 65,
#          '2748': 64,
#          '同步': 63,
#          '題材': 62,
#          '緯創': 61,
#          '超過': 60,
#          '雄獅': 60,
#          '早盤': 59,
#          '公布': 58,
#          '聯電': 57,
#          '國際': 57,
#          '相對': 57,
#          '長榮航': 57,
#          '概念股': 56,
#          '今天': 56,
#          '2023年': 56,
#          '報導': 55,
#          '權值股': 54,
#          '方面': 54,
#          '以及': 54,
#          '以上': 53,
#          '收盤': 53,
#          '目前': 53,
#          '航空': 52,
#          '晶華': 52,
#          '半導體': 52,
#          '公司': 52,
#          '買超': 51,
#          '走勢': 51,
#          '雙雄': 50,
#          '不過': 50,
#          '關卡': 50,
#          '5706': 50,
#          '旅遊': 50,
#          '16': 50,
#          '來到': 50,
#          '亮燈': 49,
#          '航運': 49,
#          '維持': 49,
#          '廣達': 49,
#          '飯店': 49,
#          '個股': 48,
#          '盤面': 48,
#          '整理': 48,
#          '買盤': 48,
#          '走揚': 48,
#          '新台幣': 48,
#          '投信': 48,
#          '燦星旅': 48,
#          '11': 48,
#          '其他': 47,
#          '勁揚': 47,
#          '六福': 47,
#          '平盤': 47,
#          '編輯': 47,
#          '投資': 47,
#          '華航': 47,
#          'IC': 47,
#          '開低': 46,
#          '以來': 46,
#          '漲多': 46,
#          '賣壓': 46,
#          '成長': 46,
#          '走低': 45,
#          '包括': 45,
#          '創意': 45,
#          '世芯': 45,
#          '金額': 45,
#          '五福': 45,
#          '交易': 45,
#          '開盤': 44,
#          '金融': 44,
#          '財報': 44,
#          '受惠': 44,
#          '漲跌': 44,
#          '6月': 44,
#          '激勵': 44,
#          '上市': 44,
#          '去年': 43,
#          '產業': 43,
#          '攻上': 43,
#          '反彈': 43,
#          '近期': 43,
#          '政策': 43,
#          '老爺知': 43,
#          '開高': 43,
#          '20': 43,
#          '高點': 42,
#          '殖利率': 42,
#          '之上': 42,
#          '分析師': 42,
#          '操作': 42,
#          '2736': 42,
#          '設計': 42,
#          '收在': 41,
#          '月線': 41,
#          '升息': 41,
#          '短線': 41,
#          '看好': 41,
#          '23': 41,
#          '高檔': 41,
#          '收斂': 41,
#          '行情': 41,
#          '亞都': 40,
#          '尾盤': 40,
#          '小漲': 40,
#          '累計': 40,
#          '2317': 39,
#          '營運': 39,
#          '影響': 39,
#          '呈現': 39,
#          '資訊': 39,
#          '成交': 39,
#          '自營商': 39,
#          '股票': 39,
#          '漲勢': 39,
#          '旺季': 39,
#          '支撐': 38,
#          '可望': 38,
#          '需求': 38,
#          '輪動': 38,
#          'BR': 38,
#          '翻黑': 38,
#          '2719': 38,
#          '緯穎': 38,
#          '5月': 38,
#          '觀察': 37,
#          '再度': 37,
#          '中央社': 37,
#          '部分': 37,
#          '業績': 37,
#          '突破': 37,
#          '歷史': 37,
#          '3231': 37,
#          '留意': 36,
#          '12': 36,
#          '15': 35,
#          '5704': 35,
#          '優於': 35,
#          '數據': 35,
#          '拉回': 35,
#          '作收': 35,
#          '大關': 35,
#          '電子股': 34,
#          '強勁': 34,
#          '均線': 34,
#          '大立光': 34,
#          '長榮': 34,
#          '翻紅': 34,
#          '分別': 34,
#          '合計': 34,
#          '24': 34,
#          '創下': 34,
#          '金融股': 33,
#          '受到': 33,
#          '逆勢': 33,
#          '價格': 33,
#          '王品': 33,
#          '易飛網': 33,
#          '兩岸': 33,
#          '證券': 33,
#          '挑戰': 33,
#          '新天地': 32,
#          '22': 32,
#          '衝上': 32,
#          '聯準會': 32,
#          '高價': 32,
#          '站上': 32,
#          '所有': 32,
#          '14': 32,
#          '小跌': 32,
#          '500': 32,
#          '2618': 32,
#          '3443': 32,
#          '11月': 32,
#          '國賓': 31,
#          '8940': 31,
#          '2731': 31,
#          '第一': 31,
#          '山富': 31,
#          '經濟': 31,
#          '機會': 31,
#          '上揚': 31,
#          '31': 31,
#          '認為': 31,
#          '進行': 31,
#          '季線': 31,
#          '技嘉': 31,
#          '3661': 31,
#          '日線': 30,
#          '拖累': 30,
#          '整體': 30,
#          '道瓊': 30,
#          '2303': 30,
#          '盤中': 30,
#          '壓力': 30,
#          '附近': 30,
#          '亞洲': 30,
#          '指出': 30,
#          '股利': 30,
#          '2705': 30,
#          '大幅': 30,
#          '昨日': 30,
#          '公告': 30,
#          '股王': 30,
#          '建議': 30,
#          '大跌': 29,
#          '台達電': 29,
#          '全面': 29,
#          '群創': 29,
#          '失守': 29,
#          '遠雄': 29,
#          '3月': 29,
#          '投資人': 29,
#          '回檔': 29,
#          '50': 29,
#          '2610': 29,
#          '軍工': 29,
#          '2745': 29,
#          '盈餘': 29,
#          '重挫': 28,
#          '收黑': 28,
#          '由於': 28,
#          '合併': 28,
#          '裕民': 28,
#          '技術面': 28,
#          '進入': 28,
#          '1.5': 28,
#          '互見': 28,
#          '此外': 28,
#          '現金': 28,
#          '華園': 27,
#          '強漲': 27,
#          '推升': 27,
#          '2707': 27,
#          '美元': 27,
#          '輝達': 27,
#          '顯示': 27,
#          '空間': 27,
#          '生技': 27,
#          '汽車': 27,
#          '收紅': 27,
#          '信驊': 27,
#          '延續': 27,
#          '日期': 27,
#          '同樣': 26,
#          '下挫': 26,
#          '日月光': 26,
#          '弱勢': 26,
#          '加碼': 26,
#          '投顧': 26,
#          '萬海': 26,
#          '2月': 26,
#          '風險': 26,
#          '21': 26,
#          '主要': 26,
#          '出現': 26,
#          '持股': 26,
#          '明年': 26,
#          '力旺': 26,
#          '27': 26,
#          '祥碩': 26,
#          '收復': 26,
#          '拉抬': 26,
#          '指標': 26,
#          '名稱': 26,
#          '增加': 26,
#          '三雄': 25,
#          '綠能': 25,
#          '投控': 25,
#          '業者': 25,
#          '5703': 25,
#          '開始': 25,
#          '新聞': 25,
#          '關注': 25,
#          '利率': 25,
#          '明顯': 25,
#          '可能': 25,
#          'Fed': 25,
#          '領軍': 25,
#          '波段': 25,
#          '28': 25,
#          '後續': 25,
#          '熱門': 25,
#          '2024年': 25,
#          '26': 25,
#          '傳產': 24,
#          '貨櫃': 24,
#          '跌破': 24,
#          '餐飲': 24,
#          'EPS': 24,
#          '成交值': 24,
#          '通膨': 24,
#          '預計': 24,
#          '2712': 24,
#          '25': 24,
#          '未來': 24,
#          '展望': 24,
#          '預估': 24,
#          '2382': 24,
#          '半年線': 24,
#          '6669': 24,
#          '5274': 24,
#          '-KY': 24,
#          '會議': 24,
#          'ADR': 23,
#          '200': 23,
#          '走跌': 23,
#          '13': 23,
#          '雖然': 23,
#          '亮眼': 23,
#          '權值': 23,
#          '雲集': 23,
#          '18': 23,
#          '逼近': 23,
#          '英業達': 23,
#          '擴大': 23,
#          '有望': 23,
#          '商機': 23,
#          '年增': 23,
#          '點火': 23,
#          '概念': 23,
#          '華城': 22,
#          '成為': 22,
#          '晶圓': 22,
#          '天地': 22,
#          '科技股': 22,
#          '強攻': 22,
#          '19': 22,
#          '記憶體': 22,
#          '新興': 22,
#          '短期': 22,
#          '陷入': 22,
#          '開出': 22,
#          '17': 22,
#          '解析': 22,
#          '全球': 22,
#          '中小型': 22,
#          '趨勢': 22,
#          '公開': 22,
#          '出籠': 22,
#          '連續': 22,
#          '12月': 22,
#          '決議': 22,
#          '開放': 21,
#          '宣布': 21,
#          '另外': 21,
#          '雷虎': 21,
#          '隨著': 21,
#          '疫情': 21,
#          '區間': 21,
#          '陽明': 21,
#          '沒有': 21,
#          '2606': 21,
#          '參考': 21,
#          '科技': 21,
#          '漢翔': 21,
#          '造紙': 21,
#          '電機': 21,
#          '3008': 21,
#          '旅展': 21,
#          '2734': 21,
#          '集中': 21,
#          '利多': 21,
#          '統一': 21,
#          '第三': 21,
#          '3529': 21,
#          '不錯': 21,
#          '永豐餘': 21,
#          '高達': 20,
#          '大量': 20,
#          '即將': 20,
#          '美債': 20,
#          '紀錄': 20,
#          '第四': 20,
#          '散裝': 20,
#          '回升': 20,
#          '年線': 20,
#          '收跌': 20,
#          '召開': 20,
#          '漲跌幅': 20,
#          '修正': 20,
#          '時間': 20,
#          '布局': 20,
#          '登場': 20,
#          '股東會': 20,
#          '2704': 20,
#          '走強': 20,
#          '航太': 20,
#          '交易日': 20,
#          '第三季': 20,
#          '產品': 20,
#          '暑假': 20,
#          '友達': 20,
#          '單位': 20,
#          '2603': 20,
#          '格局': 20,
#          '上攻': 20,
#          '伺服器': 20,
#          '表態': 20,
#          '通過': 20,
#          '注意': 20,
#          '籌碼面': 20,
#          '日本': 20,
#          '衝擊': 19,
#          '回測': 19,
#          '景氣': 19,
#          '低點': 19,
#          '幾乎': 19,
#          '2.5': 19,
#          '週二': 19,
#          '航運股': 19,
#          '內容': 19,
#          '元大': 19,
#          '普遍': 19,
#          '不會': 19,
#          '發表': 19,
#          '2615': 19,
#          '上周': 19,
#          '供應鏈': 19,
#          '揚智': 19,
#          '2743': 19,
#          '下滑': 19,
#          '奇鋐': 19,
#          '周二': 19,
#          '30': 19,
#          '集團': 19,
#          '事項': 19,
#          '解封': 19,
#          '財訊': 19,
#          '多方': 19,
#          '10月': 19,
#          '指標股': 18,
#          '面板': 18,
#          '雙雙': 18,
#          '繼續': 18,
#          '旅行社': 18,
#          '期間': 18,
#          '0.3': 18,
#          '飆漲': 18,
#          '中國': 18,
#          '國內': 18,
#          '董事會': 18,
#          '衝高': 18,
#          '6643': 18,
#          '蘋果': 18,
#          '2702': 18,
#          '2605': 18,
#          '跳空': 18,
#          '鋼鐵': 18,
#          '電腦': 18,
#          '散熱': 18,
#          '雙鴻': 18,
#          '偏多': 18,
#          '加持': 18,
#          '面臨': 18,
#          '結束': 18,
#          '29': 18,
#          '消費': 18,
#          '台北電': 18,
#          '敘明': 18,
#          '4月': 18,
#          '不變': 18,
#          '法說會': 18,
#          '權王': 17,
#          '總統': 17,
#          '寶一': 17,
#          '2727': 17,
#          '補漲': 17,
#          '隨後': 17,
#          '費城': 17,
#          '龍頭': 17,
#          '觸及': 17,
#          '網通': 17,
#          '觀望': 17,
#          '多頭': 17,
#          '05': 17,
#          '財務': 17,
#          '撐盤': 17,
#          '放量': 17,
#          '吸引': 17,
#          '回落': 17,
#          '調整': 17,
#          '下半年': 17,
#          '35': 17,
#          '譜瑞': 17,
#          '其餘': 17,
#          '最後': 17,
#          '企業': 17,
#          '改寫': 17,
#          '動能': 17,
#          '董事長': 17,
#          '基本面': 17,
#          '回溫': 17,
#          '發言人': 17,
#          '112': 17,
#          '營業': 17,
#          '股東': 17,
#          '高價股': 17,
#          '有利': 17,
#          '7月': 17,
#          '降至': 17,
#          '訂單': 17,
#          '力道': 17,
#          '3481': 17,
#          '後市': 17,
#          '統計': 17,
#          '1907': 17,
#          '漲停板': 16,
#          'TW': 16,
#          '調節': 16,
#          '同時': 16,
#          '亞股': 16,
#          '尤其': 16,
#          '公債': 16,
#          '欣興': 16,
#          '美食': 16,
#          '八方': 16,
#          '決策': 16,
#          '融券': 16,
#          '漲停價': 16,
#          '業務': 16,
#          '300': 16,
#          '亞航': 16,
#          '除了': 16,
#          '分析': 16,
#          '江明晏': 16,
#          '反應': 16,
#          '續創': 16,
#          '左右': 16,
#          '重返': 16,
#          '是否': 16,
#          '休市': 16,
#          '供應': 16,
#          '一路': 16,
#          '5269': 16,
#          '3041': 16,
#          '3324': 16,
#          '勤誠': 16,
#          '日前': 16,
#          '機率': 16,
#          '週三': 16,
#          '以下': 16,
#          '來源': 16,
#          '使得': 16,
#          '資料': 16,
#          '淨利': 16,
#          '前景': 16,
#          '助攻': 16,
#          '資產': 16,
#          '用途': 16,
#          '費半': 16,
#          '快報': 16,
#          '宏碁': 16,
#          '下降': 16,
#          '動向': 16,
#          '實際': 16,
#          '旗下': 15,
#          '消息': 15,
#          '抗跌': 15,
#          '焦點': 15,
#          '中興電': 15,
#          '恢復': 15,
#          '8222': 15,
#          '配息': 15,
#          '力麗店': 15,
#          '0.23': 15,
#          '40': 15,
#          '那斯達克': 15,
#          '代工': 15,
#          '走弱': 15,
#          '盤勢': 15,
#          '可以': 15,
#          '結果': 15,
#          '壓抑': 15,
#          '量能': 15,
#          '能源': 15,
#          '金像電': 15,
#          '填息': 15,
#          '官員': 15,
#          '連假': 15,
#          '傳統': 15,
#          '平均': 15,
#          '大同': 15,
#          '迅杰': 15,
#          '2609': 15,
#          '川湖': 15,
#          '60': 15,
#          '全數': 15,
#          '逐步': 15,
#          '2376': 15,
#          '周一': 15,
#          '齊揚': 15,
#          '積極': 15,
#          '大陸': 15,
#          '人氣': 15,
#          '持有': 15,
#          '穩定': 15,
#          '回補': 15,
#          '設備': 15,
#          '寫下': 14,
#          '標普': 14,
#          '晶心科': 14,
#          '帶量': 14,
#          '重要': 14,
#          '5364': 14,
#          '慧洋': 14,
#          '4.5': 14,
#          '國巨': 14,
#          '0.6': 14,
#          '聚焦': 14,
#          '材料': 14,
#          '籌碼': 14,
#          '買賣': 14,
#          '銷售': 14,
#          '一度': 14,
#          '進一步': 14,
#          '了結': 14,
#          '部位': 14,
#          '上升': 14,
#          '攻勢': 14,
#          '醫療': 14,
#          '通路': 14,
#          '上櫃': 14,
#          '上下': 14,
#          '站穩': 14,
#          '0.5': 14,
#          '樂觀': 14,
#          '晶片': 14,
#          '中小型股': 14,
#          '第二': 14,
#          '聯詠': 14,
#          '有限': 14,
#          '進場': 14,
#          '強彈': 14,
#          '1月': 14,
#          '方式': 14,
#          '為主': 14,
#          '創高': 14,
#          '政府': 14,
#          '天價': 14,
#          '2409': 14,
#          '復甦': 14,
#          '湧入': 14,
#          '還是': 14,
#          '李慧蘭': 14,
#          '權息': 14,
#          '華紙': 14,
#          '大廠': 13,
#          '水準': 13,
#          '下探': 13,
#          '愛普': 13,
#          '8033': 13,
#          '交易量': 13,
#          '虧損': 13,
#          'Nvidia': 13,
#          '水泥': 13,
#          '貢獻': 13,
#          '近日': 13,
#          '不斷': 13,
#          '觀光類': 13,
#          '領漲': 13,
#          '華邦電': 13,
#          '中航': 13,
#          '志信': 13,
#          '瓦城': 13,
#          '服務': 13,
#          '選股': 13,
#          '南光': 13,
#          '融資': 13,
#          '效應': 13,
#          '熄火': 13,
#          '造紙股': 13,
#          '對於': 13,
#          '海灣': 13,
#          '代表': 13,
#          '2368': 13,
#          '收高': 13,
#          '跌勢': 13,
#          '展開': 13,
#          '2634': 13,
#          '拉升': 13,
#          '生技股': 13,
#          '疲弱': 13,
#          '台耀': 13,
#          '6243': 13,
#          '4966': 13,
#          '收漲': 13,
#          '期待': 13,
#          '第四季': 13,
#          '提供': 13,
#          '爆量': 13,
#          '討論': 13,
#          '傳產股': 13,
#          '放大': 13,
#          '只要': 13,
#          '經紀人': 13,
#          '發行': 13,
#          '選舉': 13,
#          'IP': 13,
#          '相當': 13,
#          '過去': 13,
#          '運算': 13,
#          '大型': 13,
#          '紛紛': 13,
#          '多單': 13,
#          '重電': 13,
#          '3.5': 13,
#          '挺進': 13,
#          '視為': 13,
#          '長期': 13,
#          '收盤價': 13,
#          '疲軟': 12,
#          '國泰金': 12,
#          '樂事': 12,
#          '6533': 12,
#          '兆豐金': 12,
#          '開發金': 12,
#          '焦點股': 12,
#          '停板': 12,
#          '可期': 12,
#          '甚至': 12,
#          '45': 12,
#          '推動': 12,
#          '接棒': 12,
#          '信心': 12,
#          '四維航': 12,
#          '6000': 12,
#          '小幅': 12,
#          '旅遊股': 12,
#          '2612': 12,
#          '事業': 12,
#          '協商': 12,
#          '發酵': 12,
#          '2630': 12,
#          '寶得利': 12,
#          '關係': 12,
#          '保證': 12,
#          '經營': 12,
#          '2356': 12,
#          '端午': 12,
#          '80': 12,
#          '除息': 12,
#          '事欣科': 12,
#          '建準': 12,
#          '2421': 12,
#          '3017': 12,
#          '合一': 12,
#          '威剛': 12,
#          '多數': 12,
#          '年底': 12,
#          '綜合': 12,
#          'FED': 12,
#          '守住': 12,
#          '包含': 12,
#          '帶來': 12,
#          '32': 12,
#          '健策': 12,
#          '威盛': 12,
#          '2024': 12,
#          '低檔': 12,
#          '之下': 12,
#          '特別': 12,
#          '1519': 12,
#          '內需': 12,
#          '股份': 12,
#          '報告': 12,
#          '委員會': 12,
#          '陳重憲': 12,
#          '旅客': 12,
#          '華孚': 12,
#          '依舊': 12,
#          '狀況': 12,
#          '回到': 12,
#          '個人': 12,
#          '重登': 12,
#          '續強': 12,
#          '賣出': 12,
#          '2023': 12,
#          '週一': 12,
#          '1905': 12,
#          '營商': 12,
#          '8月': 12,
#          '作帳': 12,
#          '幅度': 11,
#          '利空': 11,
#          '1584': 11,
#          '空頭': 11,
#          '目標': 11,
#          '純益': 11,
#          '酒店': 11,
#          '反攻': 11,
#          '截至': 11,
#          '中小': 11,
#          '型股': 11,
#          '0.7': 11,
#          '通通': 11,
#          'BDI': 11,
#          '衛星': 11,
#          '陸續': 11,
#          '方向': 11,
#          '評估': 11,
#          '跌停': 11,
#          '0.18': 11,
#          '0.34': 11,
#          '利益': 11,
#          '開發': 11,
#          '股東常會': 11,
#          'PCB': 11,
#          '萬七': 11,
#          '9.9': 11,
#          '0.61': 11,
#          '追高': 11,
#          '上半年': 11,
#          '同期': 11,
#          '準備': 11,
#          '狹幅': 11,
#          '各自': 11,
#          '轉趨': 11,
#          '態勢': 11,
#          '飯店股': 11,
#          '攻高': 11,
#          '0.25': 11,
#          '583': 11,
#          '不足': 11,
#          '比重': 11,
#          '樺漢': 11,
#          '光寶科': 11,
#          '電動車': 11,
#          '餐飲股': 11,
#          '出貨': 11,
#          '已經': 11,
#          '主席': 11,
#          '大舉': 11,
#          '矽力': 11,
#          '0.01': 11,
#          '16日': 11,
#          '休息': 11,
#          '2637': 11,
#          '5608': 11,
#          '1513': 11,
#          '龍彩霖': 11,
#          '事實': 11,
#          '發生日': 11,
#          '董事': 11,
#          '最近': 11,
#          '說明': 11,
#          '尚未': 11,
#          '年度': 11,
#          '23日': 11,
#          '驗證': 11,
#          '周三': 11,
#          '亞德客': 11,
#          '股息': 11,
#          '逐漸': 11,
#          '買進': 11,
#          '變化': 11,
#          '高速': 11,
#          '賣超': 11,
#          '攻頂': 11,
#          '矽智財': 11,
#          '轉為': 11,
#          '2059': 11,
#          '生醫': 11,
#          '會計': 11,
#          '碳權': 11,
#          '上限': 11,
#          '微軟': 11,
#          '買氣': 11,
#          '油電': 11,
#          '任何': 11,
#          '台塑': 11,
#          '回流': 11,
#          '彈升': 11,
#          '4916': 11,
#          '2371': 11,
#          '不宜': 11,
#          '聲明': 11,
#          '餐旅': 11,
#          '理財': 11,
#          '義務': 11,
#          '庫存': 10,
#          '標的': 10,
#          '6531': 10,
#          '買單': 10,
#          '精剛': 10,
#          '青睞': 10,
#          '而言': 10,
#          '擔憂': 10,
#          '聯袂': 10,
#          '基期': 10,
#          '轉強': 10,
#          '老爺': 10,
#          '單季': 10,
#          '可能性': 10,
#          '回穩': 10,
#          '年期': 10,
#          '南亞科': 10,
#          '華碩': 10,
#          '走升': 10,
#          '力守': 10,
#          '因為': 10,
#          '2611': 10,
#          '文曄': 10,
#          '月份': 10,
#          '壓回': 10,
#          '主流': 10,
#          '啟動': 10,
#          '債務': 10,
#          '營建股': 10,
#          '降溫': 10,
#          '工業': 10,
#          'https': 10,
#          '搶眼': 10,
#          '全新': 10,
#          '氣勢': 10,
#          '2753': 10,
#          '碩天': 10,
#          '巴黎': 10,
#          '位置': 10,
#          '百貨': 10,
#          '4746': 10,
#          '稅務': 10,
#          '鬆綁': 10,
#          '收入': 10,
#          '8210': 10,
#          '凌陽': 10,
#          '單日': 10,
#          '中天': 10,
#          '大選': 10,
#          '發揮': 10,
#          '穩盤': 10,
#          '42.4': 10,
#          '轉向': 10,
#          '情況': 10,
#          '重回': 10,
#          '就是': 10,
#          '釋出': 10,
#          '處理': 10,
#          '適用': 10,
#          '損失': 10,
#          ...})

# %%
tf_counter_bull
# Out:
# Counter({'指數': 661,
#          '台股': 548,
#          '股價': 437,
#          '夏都': 364,
#          '觀光': 362,
#          '上漲': 345,
#          '漲停': 341,
#          '表現': 286,
#          '漲幅': 266,
#          '類股': 261,
#          '族群': 258,
#          '台積電': 248,
#          '外資': 247,
#          '今日': 237,
#          '下跌': 236,
#          '震盪': 214,
#          '市場': 211,
#          'TW': 207,
#          '2722': 206,
#          '法人': 199,
#          '寒舍': 190,
#          '台北': 186,
#          '公司': 174,
#          '美股': 168,
#          '跌幅': 165,
#          'KY': 165,
#          '電子': 163,
#          'AI': 163,
#          '終場': 162,
#          '持續': 162,
#          '美國': 159,
#          '買超': 158,
#          '聯發科': 155,
#          '大漲': 155,
#          '今年': 154,
#          '交易': 152,
#          '股市': 149,
#          '營收': 147,
#          '強勢': 145,
#          '早盤': 144,
#          '新高': 143,
#          '雲品': 135,
#          '帶動': 133,
#          '觀光股': 132,
#          '資金': 124,
#          '10': 120,
#          '加權': 119,
#          '今天': 115,
#          '預期': 113,
#          '鳳凰': 112,
#          '表示': 111,
#          '獲利': 111,
#          '題材': 108,
#          '超過': 105,
#          '加上': 100,
#          '成交量': 100,
#          '旅遊': 100,
#          '台灣': 97,
#          '2330': 96,
#          '2739': 95,
#          '反彈': 95,
#          'BR': 95,
#          '公布': 93,
#          '同步': 92,
#          '航空': 92,
#          '大盤': 92,
#          '鴻海': 91,
#          '走高': 91,
#          '相關': 90,
#          '收盤': 90,
#          '個股': 86,
#          '其中': 85,
#          '概念股': 82,
#          '國際': 82,
#          '來到': 82,
#          '方面': 81,
#          '投資': 81,
#          '權值股': 79,
#          '記者': 79,
#          '以及': 79,
#          '金額': 79,
#          '不過': 78,
#          '飯店': 78,
#          '去年': 77,
#          '亮燈': 77,
#          '2454': 76,
#          '營運': 75,
#          '相對': 74,
#          '以來': 74,
#          '富野': 74,
#          '走勢': 74,
#          '買盤': 73,
#          '航運': 73,
#          '維持': 73,
#          '投信': 73,
#          '時報': 73,
#          '目前': 73,
#          '盤面': 72,
#          '雄獅': 72,
#          '緯創': 72,
#          '數據': 71,
#          '資訊': 71,
#          '兩岸': 71,
#          '發行': 71,
#          '晶華': 70,
#          '關卡': 69,
#          '以上': 69,
#          '短線': 69,
#          '股東會': 69,
#          '價格': 68,
#          '漲多': 68,
#          '半導體': 68,
#          '2748': 68,
#          '殖利率': 68,
#          '財報': 68,
#          'IC': 68,
#          '升息': 67,
#          '適用': 67,
#          '開低': 66,
#          '產業': 66,
#          '賣壓': 66,
#          '走揚': 66,
#          '突破': 66,
#          '長榮航': 66,
#          '聯電': 65,
#          '勁揚': 65,
#          '平盤': 65,
#          '尾盤': 65,
#          '5月': 65,
#          '包括': 64,
#          '雙雄': 64,
#          '高點': 64,
#          '金融': 64,
#          '行情': 64,
#          '證券': 64,
#          '自營商': 63,
#          '五福': 63,
#          '成長': 63,
#          '其他': 62,
#          '新台幣': 62,
#          '16': 62,
#          '拉回': 62,
#          '11': 62,
#          '季線': 62,
#          '合併': 61,
#          '受惠': 61,
#          '留意': 61,
#          '小漲': 61,
#          '廣達': 61,
#          '燦星旅': 61,
#          '上市': 61,
#          '累計': 61,
#          '盈餘': 61,
#          '月線': 60,
#          '歷史': 60,
#          '美元': 59,
#          '之上': 59,
#          '業績': 59,
#          '6月': 59,
#          '設計': 59,
#          '走低': 58,
#          '需求': 58,
#          '近期': 58,
#          '2023年': 58,
#          '開盤': 57,
#          'EPS': 57,
#          '翻黑': 57,
#          '激勵': 57,
#          '日期': 57,
#          '旺季': 56,
#          '整理': 55,
#          '5706': 55,
#          '報導': 55,
#          '公告': 55,
#          '可望': 54,
#          '六福': 54,
#          '影響': 54,
#          '高檔': 54,
#          '收斂': 54,
#          '攻上': 53,
#          '政策': 53,
#          '世芯': 53,
#          '華航': 53,
#          '9.9': 53,
#          '開高': 53,
#          '成交': 52,
#          '創意': 52,
#          '資料': 52,
#          '事項': 52,
#          '看好': 51,
#          '均線': 51,
#          '漲勢': 51,
#          '半年線': 51,
#          '金融股': 50,
#          '支撐': 50,
#          '聯準會': 50,
#          '23': 50,
#          '操作': 50,
#          '老爺知': 50,
#          '作收': 50,
#          '20': 50,
#          '收在': 49,
#          '觀察': 48,
#          '亞都': 48,
#          '輝達': 48,
#          '分析師': 47,
#          '呈現': 47,
#          '編輯': 47,
#          '經濟': 47,
#          '漲跌': 47,
#          '重挫': 46,
#          '大跌': 46,
#          '全面': 46,
#          '分別': 46,
#          '召開': 46,
#          '輪動': 45,
#          '翻紅': 45,
#          '山富': 45,
#          '利率': 45,
#          '部分': 45,
#          '3月': 45,
#          '股票': 45,
#          '高價': 44,
#          '股利': 44,
#          '24': 44,
#          '大關': 44,
#          '昨日': 44,
#          '緯穎': 44,
#          '日線': 43,
#          '15': 43,
#          '拖累': 43,
#          '逆勢': 43,
#          '電子股': 43,
#          '再度': 43,
#          '董事會': 43,
#          '旅展': 43,
#          '指標': 43,
#          '衝上': 42,
#          '優於': 42,
#          '2736': 42,
#          '2719': 42,
#          '112': 42,
#          '2317': 41,
#          '附近': 41,
#          '小跌': 41,
#          '機會': 41,
#          '明年': 41,
#          '創下': 41,
#          '名稱': 41,
#          '受到': 40,
#          '整體': 40,
#          '開放': 40,
#          '國賓': 40,
#          '挑戰': 40,
#          '年增': 40,
#          '現金': 40,
#          '11月': 40,
#          '收黑': 39,
#          '王品': 39,
#          '失守': 39,
#          '強勁': 39,
#          '14': 39,
#          '回檔': 39,
#          '上揚': 39,
#          '12': 39,
#          '延續': 39,
#          '建議': 39,
#          '下挫': 38,
#          '新天地': 38,
#          '22': 38,
#          '推升': 38,
#          '業者': 38,
#          '站上': 38,
#          '亞洲': 38,
#          '美食': 38,
#          '生技': 38,
#          '指出': 38,
#          '投資人': 38,
#          '收紅': 38,
#          '軍工': 38,
#          '3231': 38,
#          '增加': 38,
#          '任何': 38,
#          '8940': 37,
#          '5704': 37,
#          '中央社': 37,
#          '易飛網': 37,
#          '合計': 37,
#          '主要': 37,
#          '波段': 37,
#          '淨利': 37,
#          '股東': 37,
#          '8月': 37,
#          '10.0': 37,
#          '群創': 36,
#          '長榮': 36,
#          '風險': 36,
#          '進入': 36,
#          '31': 36,
#          '3443': 36,
#          '單位': 36,
#          '收復': 36,
#          '報告': 36,
#          '傳產': 35,
#          '壓力': 35,
#          '第一': 35,
#          '投顧': 35,
#          '大立光': 35,
#          '通膨': 35,
#          '50': 35,
#          '出現': 35,
#          '持股': 35,
#          '上周': 35,
#          '認為': 35,
#          '進行': 35,
#          '集中': 35,
#          '大量': 34,
#          '綠能': 34,
#          '盤中': 34,
#          '餐飲': 34,
#          '所有': 34,
#          '2月': 34,
#          '收跌': 34,
#          '500': 34,
#          '2705': 34,
#          '2618': 34,
#          '大幅': 34,
#          '拉抬': 34,
#          '決議': 34,
#          '處分': 34,
#          '200': 33,
#          '關注': 33,
#          '空間': 33,
#          '開出': 33,
#          '中國': 33,
#          '21': 33,
#          '財務': 33,
#          '關係': 33,
#          '格局': 33,
#          '技嘉': 33,
#          '連續': 33,
#          '會議': 33,
#          '股王': 33,
#          '營業': 33,
#          '概念': 33,
#          '日本': 33,
#          '10月': 33,
#          '同樣': 32,
#          '道瓊': 32,
#          '強漲': 32,
#          '旅行社': 32,
#          '2731': 32,
#          '加碼': 32,
#          '技術面': 32,
#          '可能': 32,
#          '逼近': 32,
#          '汽車': 32,
#          '暑假': 32,
#          '2745': 32,
#          '關係人': 32,
#          '3661': 32,
#          '日月光': 31,
#          '2303': 31,
#          '遠雄': 31,
#          '裕民': 31,
#          '年線': 31,
#          '預計': 31,
#          '全球': 31,
#          '2610': 31,
#          '領軍': 31,
#          '-KY': 31,
#          '點火': 31,
#          '召集': 31,
#          '取得': 31,
#          '董事': 31,
#          'ADR': 30,
#          '景氣': 30,
#          '投控': 30,
#          '弱勢': 30,
#          '由於': 30,
#          '開始': 30,
#          '亮眼': 30,
#          '權值': 30,
#          '雲集': 30,
#          '17': 30,
#          '擴大': 30,
#          '有望': 30,
#          '商機': 30,
#          '27': 30,
#          '此外': 30,
#          '伺服器': 30,
#          '後續': 30,
#          '12月': 30,
#          '強彈': 30,
#          '事由': 30,
#          '7月': 30,
#          '台達電': 29,
#          '2707': 29,
#          '新聞': 29,
#          '雖然': 29,
#          '顯示': 29,
#          '明顯': 29,
#          '未來': 29,
#          'Fed': 29,
#          '互見': 29,
#          '利多': 29,
#          '通過': 29,
#          '訂單': 29,
#          '華園': 28,
#          '成為': 28,
#          '走跌': 28,
#          '美債': 28,
#          '虧損': 28,
#          '科技股': 28,
#          '沒有': 28,
#          '記憶體': 28,
#          '新興': 28,
#          '盤勢': 28,
#          '融券': 28,
#          '分析': 28,
#          '預估': 28,
#          '力旺': 28,
#          '信驊': 28,
#          '1.5': 28,
#          '公開': 28,
#          '祥碩': 28,
#          '6669': 28,
#          '表態': 28,
#          '大陸': 28,
#          '董事長': 28,
#          '代號': 28,
#          '貨櫃': 27,
#          '樂事': 27,
#          '跌破': 27,
#          '隨著': 27,
#          '區間': 27,
#          '航運股': 27,
#          '萬海': 27,
#          '展望': 27,
#          '友達': 27,
#          '造紙': 27,
#          '周二': 27,
#          '熱門': 27,
#          '2024年': 27,
#          '移轉': 27,
#          '資產': 27,
#          '26': 27,
#          '周三': 27,
#          '高達': 26,
#          '消息': 26,
#          '三雄': 26,
#          '疫情': 26,
#          '5703': 26,
#          '飆漲': 26,
#          '買賣': 26,
#          '收高': 26,
#          '航太': 26,
#          '漢翔': 26,
#          '散熱': 26,
#          '28': 26,
#          '統一': 26,
#          '4月': 26,
#          '注意': 26,
#          '瀧澤科': 26,
#          '低點': 25,
#          '幾乎': 25,
#          '紀錄': 25,
#          '強攻': 25,
#          '13': 25,
#          '散裝': 25,
#          '回升': 25,
#          '短期': 25,
#          '2712': 25,
#          '張數': 25,
#          '修正': 25,
#          '時間': 25,
#          '跳空': 25,
#          '趨勢': 25,
#          '5274': 25,
#          '112年': 25,
#          '第三': 25,
#          '還是': 25,
#          '宣布': 24,
#          '雙雙': 24,
#          '週二': 24,
#          '成交值': 24,
#          '19': 24,
#          '決策': 24,
#          '25': 24,
#          '跌停': 24,
#          '元大': 24,
#          '蘋果': 24,
#          '登場': 24,
#          '2382': 24,
#          '交易日': 24,
#          '30': 24,
#          '集團': 24,
#          '會計師': 24,
#          '多方': 24,
#          '多單': 24,
#          '面板': 23,
#          '華城': 23,
#          '漲停板': 23,
#          '恢復': 23,
#          '晶圓': 23,
#          '另外': 23,
#          '雷虎': 23,
#          '帶量': 23,
#          '天地': 23,
#          '2.5': 23,
#          '陷入': 23,
#          '可以': 23,
#          '2606': 23,
#          '18': 23,
#          '觀望': 23,
#          '發表': 23,
#          '科技': 23,
#          '中小型': 23,
#          '布局': 23,
#          '英業達': 23,
#          '填息': 23,
#          '回落': 23,
#          '產品': 23,
#          '下滑': 23,
#          '偏多': 23,
#          '上攻': 23,
#          '加持': 23,
#          '改寫': 23,
#          '高價股': 23,
#          '券商': 23,
#          '即將': 22,
#          '調節': 22,
#          '交易量': 22,
#          '期間': 22,
#          '隨後': 22,
#          '龍頭': 22,
#          '多頭': 22,
#          '衝高': 22,
#          '解析': 22,
#          '走強': 22,
#          '重返': 22,
#          '放量': 22,
#          '3008': 22,
#          '揚智': 22,
#          '2734': 22,
#          '奇鋐': 22,
#          '出籠': 22,
#          '週三': 22,
#          '動能': 22,
#          '台指期': 22,
#          '重大': 22,
#          '辦理': 22,
#          '3529': 22,
#          '有利': 22,
#          '不錯': 22,
#          '籌碼面': 22,
#          '不變': 22,
#          '損益': 22,
#          '永豐餘': 22,
#          '權王': 21,
#          '總統': 21,
#          '繼續': 21,
#          '焦點股': 21,
#          '陽明': 21,
#          '公債': 21,
#          '觀光類': 21,
#          '代工': 21,
#          '0.3': 21,
#          '觸及': 21,
#          '參考': 21,
#          '增減': 21,
#          '業務': 21,
#          '05': 21,
#          '2605': 21,
#          '鋼鐵': 21,
#          '吸引': 21,
#          '連假': 21,
#          '下半年': 21,
#          '電機': 21,
#          '2743': 21,
#          '機率': 21,
#          '收漲': 21,
#          '晶片': 21,
#          '結束': 21,
#          '解封': 21,
#          '費半': 21,
#          '下降': 21,
#          '實際': 21,
#          '回測': 20,
#          '指標股': 20,
#          '抗跌': 20,
#          '配息': 20,
#          '第四': 20,
#          '貢獻': 20,
#          '走弱': 20,
#          '網通': 20,
#          '國內': 20,
#          '內容': 20,
#          '漲跌幅': 20,
#          '普遍': 20,
#          '不會': 20,
#          '續創': 20,
#          '2704': 20,
#          '2615': 20,
#          '第三季': 20,
#          '供應鏈': 20,
#          '平均': 20,
#          '電腦': 20,
#          '一路': 20,
#          '2603': 20,
#          '29': 20,
#          '回溫': 20,
#          '原因': 20,
#          '股份': 20,
#          '增資': 20,
#          '驗證': 20,
#          '天價': 20,
#          '依舊': 20,
#          '穩定': 20,
#          '降至': 20,
#          '後市': 20,
#          '權息': 20,
#          '法說會': 20,
#          '週一': 20,
#          '衝擊': 19,
#          '標普': 19,
#          '寶一': 19,
#          '尤其': 19,
#          '0.6': 19,
#          '八方': 19,
#          '6000': 19,
#          '融資': 19,
#          '300': 19,
#          '有價': 19,
#          '2702': 19,
#          '調整': 19,
#          '大同': 19,
#          '收入': 19,
#          '雙鴻': 19,
#          '譜瑞': 19,
#          '0.5': 19,
#          '面臨': 19,
#          '全數': 19,
#          '最後': 19,
#          '年底': 19,
#          '企業': 19,
#          '包含': 19,
#          '周一': 19,
#          '使得': 19,
#          '機器人': 19,
#          '有限': 19,
#          '消費': 19,
#          '只要': 19,
#          '最近': 19,
#          '敘明': 19,
#          '持有': 19,
#          '財訊': 19,
#          '宏碁': 19,
#          '矽智財': 19,
#          '回補': 19,
#          '轉為': 19,
#          '訊息': 19,
#          '純益': 18,
#          '0.23': 18,
#          '40': 18,
#          '費城': 18,
#          '結果': 18,
#          '漲停價': 18,
#          '銷售': 18,
#          '亞航': 18,
#          '除了': 18,
#          'https': 18,
#          '6643': 18,
#          '反應': 18,
#          '股東常會': 18,
#          '跌勢': 18,
#          '是否': 18,
#          '部位': 18,
#          '除息': 18,
#          '醫療': 18,
#          '35': 18,
#          '上櫃': 18,
#          '其餘': 18,
#          '以下': 18,
#          '來源': 18,
#          '基本面': 18,
#          '台北電': 18,
#          '情形': 18,
#          '方式': 18,
#          '選舉': 18,
#          '創高': 18,
#          '政府': 18,
#          '價差': 18,
#          '力道': 18,
#          '3481': 18,
#          '設備': 18,
#          '董娘': 18,
#          '113': 18,
#          '認購': 18,
#          'TOP': 18,
#          'Dcard': 18,
#          '中興電': 17,
#          '同時': 17,
#          '亞股': 17,
#          '2727': 17,
#          '停板': 17,
#          '酒店': 17,
#          '補漲': 17,
#          '信心': 17,
#          '左右': 17,
#          '代表': 17,
#          '撐盤': 17,
#          '了結': 17,
#          '端午': 17,
#          '傳統': 17,
#          '休市': 17,
#          '供應': 17,
#          '疲弱': 17,
#          '3041': 17,
#          '通路': 17,
#          '川湖': 17,
#          '42.4': 17,
#          '樂觀': 17,
#          '助攻': 17,
#          '發言人': 17,
#          '1月': 17,
#          '年度': 17,
#          '停止': 17,
#          '旅客': 17,
#          '相當': 17,
#          '大型': 17,
#          '重登': 17,
#          '挺進': 17,
#          '賣出': 17,
#          '自結': 17,
#          '統計': 17,
#          '比例': 17,
#          '團客': 17,
#          '1907': 17,
#          '上限': 17,
#          '股名': 17,
#          '旗下': 16,
#          '疲軟': 16,
#          '寫下': 16,
#          '家數': 16,
#          '重要': 16,
#          '力麗店': 16,
#          '水泥': 16,
#          '4.5': 16,
#          '欣興': 16,
#          '旅遊股': 16,
#          '月份': 16,
#          '籌碼': 16,
#          '效應': 16,
#          '選擇權': 16,
#          '江明晏': 16,
#          '能源': 16,
#          '官員': 16,
#          '進一步': 16,
#          '生技股': 16,
#          '5269': 16,
#          '3324': 16,
#          '勤誠': 16,
#          '日前': 16,
#          '上下': 16,
#          '17200': 16,
#          '60': 16,
#          '逐步': 16,
#          '2376': 16,
#          '周五': 16,
#          '齊揚': 16,
#          '威盛': 16,
#          '0.01': 16,
#          '前景': 16,
#          '討論': 16,
#          '進場': 16,
#          '人氣': 16,
#          '內需': 16,
#          '用途': 16,
#          '111': 16,
#          '快報': 16,
#          '買進': 16,
#          '變化': 16,
#          '回到': 16,
#          '2409': 16,
#          '賣超': 16,
#          '復甦': 16,
#          '外銷': 16,
#          '動向': 16,
#          '申報': 16,
#          '說明會': 16,
#          '多空': 16,
#          '本業': 16,
#          '大廠': 15,
#          '焦點': 15,
#          '士電': 15,
#          '下探': 15,
#          '買單': 15,
#          '對象': 15,
#          '8222': 15,
#          '慧洋': 15,
#          '速報': 15,
#          '國巨': 15,
#          '華邦電': 15,
#          '那斯達克': 15,
#          '志信': 15,
#          '聚焦': 15,
#          '因為': 15,
#          '評估': 15,
#          '熄火': 15,
#          '壓抑': 15,
#          '量能': 15,
#          '利益': 15,
#          '金像電': 15,
#          '萬七': 15,
#          '拉升': 15,
#          '攻勢': 15,
#          '迅杰': 15,
#          '2609': 15,
#          '機殼': 15,
#          '合一': 15,
#          '威剛': 15,
#          '大選': 15,
#          '站穩': 15,
#          '帶來': 15,
#          '中小型股': 15,
#          '第二': 15,
#          '積極': 15,
#          '大舉': 15,
#          '聯詠': 15,
#          '低檔': 15,
#          '放大': 15,
#          '特別': 15,
#          '說明': 15,
#          '規定': 15,
#          '員工': 15,
#          '為主': 15,
#          '狀況': 15,
#          'RSI': 15,
#          'KD': 15,
#          '大成': 15,
#          '3.5': 15,
#          '台塑': 15,
#          '回流': 15,
#          '餐旅': 15,
#          '理財': 15,
#          '股數': 15,
#          '卜蜂': 15,
#          '利空': 14,
#          '國泰金': 14,
#          '水準': 14,
#          '標的': 14,
#          '晶心科': 14,
#          '兆豐金': 14,
#          '空頭': 14,
#          '5364': 14,
#          '15600': 14,
#          '領漲': 14,
#          '0.7': 14,
#          '通通': 14,
#          '瓦城': 14,
#          '服務': 14,
#          '陸續': 14,
#          '選股': 14,
#          '文曄': 14,
#          '材料': 14,
#          '事業': 14,
#          '協商': 14,
#          '發酵': 14,
#          '分享': 14,
#          '寶得利': 14,
#          '開發': 14,
#          '一度': 14,
#          '展開': 14,
#          '上升': 14,
#          '同期': 14,
#          '80': 14,
#          '事欣科': 14,
#          '鬆綁': 14,
#          '建準': 14,
#          '藍白': 14,
#          '期待': 14,
#          '不足': 14,
#          '第四季': 14,
#          'FED': 14,
#          '提供': 14,
#          '就是': 14,
#          '出貨': 14,
#          '之下': 14,
#          '估價': 14,
#          '委員會': 14,
#          '過戶': 14,
#          '23日': 14,
#          '過去': 14,
#          '運算': 14,
#          '湧入': 14,
#          '重電': 14,
#          '李慧蘭': 14,
#          '生醫': 14,
#          '母公司': 14,
#          '長期': 14,
#          '2023': 14,
#          '高峰': 14,
#          '華紙': 14,
#          '韓國': 14,
#          '政治': 13,
#          '愛普': 13,
#          '8033': 13,
#          '目標': 13,
#          '基期': 13,
#          '單季': 13,
#          '可期': 13,
#          '甚至': 13,
#          'Nvidia': 13,
#          '45': 13,
#          '近日': 13,
#          '不斷': 13,
#          '09': 13,
#          'BDI': 13,
#          '中航': 13,
#          '四維航': 13,
#          '小幅': 13,
#          '南光': 13,
#          '壓回': 13,
#          '債務': 13,
#          '0.06': 13,
#          '造紙股': 13,
#          '對於': 13,
#          '2630': 13,
#          '海灣': 13,
#          '全新': 13,
#          '經營': 13,
#          '2368': 13,
#          '2634': 13,
#          '上半年': 13,
#          '台耀': 13,
#          '6243': 13,
#          '3017': 13,
#          '4966': 13,
#          '單日': 13,
#          '中天': 13,
#          '多數': 13,
#          '實體': 13,
#          '32': 13,
#          '爆量': 13,
#          '釋出': 13,
#          '2024': 13,
#          '處理': 13,
#          '休息': 13,
#          '傳產股': 13,
#          '亞力': 13,
#          '土地': 13,
#          '台南市': 13,
#          '尚未': 13,
#          '經紀人': 13,
#          '事宜': 13,
#          '陳重憲': 13,
#          '智原': 13,
#          'IP': 13,
#          '紛紛': 13,
#          '引發': 13,
#          '成分股': 13,
#          '房價': 13,
#          '2388': 13,
#          '配發': 13,
#          '續強': 13,
#          '但是': 13,
#          '發生': 13,
#          '視為': 13,
#          '問題': 13,
#          '碳權': 13,
#          '微軟': 13,
#          '營商': 13,
#          '彈升': 13,
#          '收盤價': 13,
#          '庫存': 12,
#          '地緣': 12,
#          '6533': 12,
#          '開發金': 12,
#          '回穩': 12,
#          '反攻': 12,
#          '推動': 12,
#          '接棒': 12,
#          '華碩': 12,
#          '走升': 12,
#          '衛星': 12,
#          '方向': 12,
#          '2612': 12,
#          '2611': 12,
#          '降溫': 12,
#          '保證': 12,
#          '搶眼': 12,
#          '2356': 12,
#          '0.61': 12,
#          '準備': 12,
#          '百貨': 12,
#          '2421': 12,
#          '狹幅': 12,
#          '各自': 12,
#          '迎廣': 12,
#          ...})

# %%
tf_counter_bear = Counter()
df_counter_bear = Counter()

f = open('2722_Bear_news.csv', newline='', encoding='utf-8')
rows = csv.reader(f, delimiter=',')
i = 0
for row in rows:
    # print(row[1], row[2])
    i = i + 1
    if i > 1:
        query = row[1]+' ' + row[2]
        df_temp = Counter()
        sentence_list = utils.short_sentence(query)
        for item in sentence_list:
            word_cut = monpa.cut(item)
            for term in word_cut:
                term = term.strip()
                if (len(term) > 1):
                    tf_counter_bear[term] += 1
                    if (df_temp[term] == 0):
                        df_temp[term] = 1
        df_counter_bear += df_temp

f.close()

# %%
tf_counter_bear
# Out:
# Counter({'台股': 384,
#          '指數': 383,
#          '觀光': 332,
#          '股價': 329,
#          '夏都': 271,
#          '漲幅': 251,
#          '上漲': 245,
#          '族群': 238,
#          '表現': 229,
#          '漲停': 220,
#          '今日': 218,
#          '下跌': 195,
#          '台積電': 180,
#          '法人': 178,
#          'AI': 176,
#          '類股': 175,
#          '公司': 174,
#          '外資': 167,
#          '今年': 163,
#          '市場': 152,
#          '持續': 142,
#          'KY': 136,
#          '營收': 134,
#          '震盪': 129,
#          '大漲': 124,
#          '跌幅': 124,
#          '台北': 123,
#          '2722': 120,
#          '10': 119,
#          '終場': 119,
#          '電子': 116,
#          '寒舍': 112,
#          '投資': 112,
#          '觀光股': 111,
#          '美股': 111,
#          '早盤': 110,
#          '題材': 108,
#          '概念股': 106,
#          '收盤': 102,
#          '台灣': 97,
#          '旅遊': 97,
#          '飯店': 96,
#          '兩岸': 95,
#          '雲品': 95,
#          '獲利': 93,
#          '上市': 93,
#          '資金': 91,
#          '新高': 90,
#          '加權': 90,
#          '股市': 89,
#          '買超': 86,
#          '國際': 86,
#          '鳳凰': 86,
#          '超過': 85,
#          '股東會': 84,
#          '相關': 84,
#          '產業': 83,
#          '以上': 82,
#          '成交量': 82,
#          '大盤': 82,
#          '個股': 81,
#          '今天': 81,
#          '帶動': 80,
#          '其中': 80,
#          '表示': 80,
#          '加上': 79,
#          '方面': 79,
#          '雄獅': 78,
#          '數據': 77,
#          '強勢': 76,
#          '鴻海': 75,
#          '預期': 74,
#          '長榮航': 74,
#          '目前': 73,
#          '走高': 73,
#          '半導體': 71,
#          '政策': 70,
#          '中環': 69,
#          '金融': 68,
#          '記者': 68,
#          '交易': 68,
#          '聯發科': 67,
#          '不過': 66,
#          '成長': 65,
#          '來到': 65,
#          '投信': 65,
#          '航空': 65,
#          '緯創': 65,
#          '召開': 65,
#          '開高': 64,
#          '20': 64,
#          '廣達': 64,
#          '去年': 63,
#          '賣壓': 63,
#          '其他': 63,
#          '美國': 63,
#          '事項': 63,
#          '盤面': 62,
#          '行情': 62,
#          '證券': 61,
#          '營運': 60,
#          '激勵': 60,
#          '走勢': 60,
#          '15': 60,
#          '晶華': 59,
#          '6月': 59,
#          '聯電': 58,
#          '可望': 58,
#          '翻紅': 57,
#          '平盤': 57,
#          'BR': 57,
#          '11': 57,
#          '影響': 57,
#          '日期': 57,
#          '富野': 56,
#          '報導': 56,
#          '召集': 56,
#          '亮燈': 55,
#          '開盤': 55,
#          '明年': 55,
#          '事由': 54,
#          '包括': 53,
#          '華航': 53,
#          '相對': 53,
#          '資料': 53,
#          '產品': 53,
#          '受惠': 52,
#          '2023年': 52,
#          '恢復': 51,
#          '同步': 51,
#          '旺季': 51,
#          '融券': 51,
#          '報告': 51,
#          '3月': 50,
#          '月線': 50,
#          '航運': 49,
#          '2330': 49,
#          '長榮': 49,
#          '收紅': 49,
#          '股東': 49,
#          '7月': 49,
#          '王品': 48,
#          '自營商': 48,
#          '短線': 48,
#          '12': 48,
#          '機會': 48,
#          '反彈': 47,
#          '關卡': 47,
#          '站上': 47,
#          '山富': 47,
#          '第一': 47,
#          '2024年': 47,
#          '部分': 46,
#          '權值股': 46,
#          '走揚': 46,
#          '歷史': 46,
#          '近期': 46,
#          '融資': 46,
#          '股票': 46,
#          '時報': 46,
#          '以及': 45,
#          '買盤': 45,
#          '翻黑': 45,
#          '建議': 45,
#          '疫情': 44,
#          '大立光': 44,
#          '商機': 44,
#          '員工': 44,
#          '五福': 44,
#          '雙雄': 43,
#          '盈餘': 43,
#          '9.9': 43,
#          '需求': 42,
#          '業績': 42,
#          '新聞': 42,
#          '業者': 42,
#          '113': 42,
#          '傳產': 42,
#          '5月': 42,
#          '公告': 41,
#          '大關': 41,
#          '觀察': 41,
#          '漲勢': 41,
#          '全面': 41,
#          '財報': 41,
#          '六福': 41,
#          '2739': 41,
#          '餐飲': 40,
#          '收在': 40,
#          '出現': 40,
#          '勁揚': 40,
#          '全球': 40,
#          '漲跌': 40,
#          '電子股': 40,
#          '指出': 40,
#          '公布': 39,
#          '期間': 39,
#          '拖累': 39,
#          '成交': 38,
#          '緯穎': 38,
#          '資訊': 38,
#          '高檔': 38,
#          '升息': 38,
#          '設備': 38,
#          '任何': 38,
#          '同樣': 37,
#          '上櫃': 37,
#          '整體': 37,
#          '總統': 37,
#          '軍工': 37,
#          '16': 37,
#          '訂單': 37,
#          '旅行社': 36,
#          '以來': 36,
#          '收斂': 36,
#          '燦星旅': 36,
#          '整理': 36,
#          '買賣': 36,
#          '薪資': 36,
#          '綠能': 36,
#          '概念': 36,
#          '營業': 36,
#          '分別': 35,
#          '留意': 35,
#          '走低': 35,
#          '小漲': 35,
#          'TW': 35,
#          '美元': 35,
#          '112': 35,
#          '看好': 35,
#          '政府': 34,
#          '合計': 34,
#          '隨著': 34,
#          '主要': 34,
#          '投資人': 34,
#          '成為': 34,
#          '釋出': 34,
#          '再度': 34,
#          '內容': 34,
#          '作收': 34,
#          '發展': 34,
#          '未來': 34,
#          '宣布': 34,
#          '周三': 34,
#          '波段': 34,
#          '董事': 34,
#          '投控': 34,
#          '企業': 33,
#          '14': 33,
#          '美食': 33,
#          '生技': 33,
#          '陽明': 33,
#          '2748': 33,
#          '可能': 33,
#          '通膨': 33,
#          '多方': 33,
#          '分析': 33,
#          '1月': 32,
#          '另外': 32,
#          '受到': 32,
#          '時間': 32,
#          '尾盤': 32,
#          '強漲': 32,
#          '拉回': 32,
#          '散熱': 32,
#          '11月': 32,
#          '5706': 32,
#          '4月': 32,
#          '品牌': 32,
#          '價格': 32,
#          '中國': 31,
#          '開低': 31,
#          '下挫': 31,
#          '盤勢': 31,
#          '放量': 31,
#          '2317': 31,
#          '優於': 31,
#          '伺服器': 31,
#          '法說會': 31,
#          '統一': 31,
#          'ADR': 31,
#          '有望': 31,
#          '均線': 31,
#          '統計': 31,
#          '增加': 30,
#          '突破': 30,
#          '30': 30,
#          '利多': 30,
#          '漲多': 30,
#          '2454': 30,
#          '展望': 30,
#          '收黑': 30,
#          '亞洲': 30,
#          '擴大': 30,
#          '交易日': 30,
#          '聯準會': 30,
#          '名稱': 30,
#          '持股': 30,
#          '維持': 30,
#          '蘋果': 30,
#          '積極': 30,
#          '代號': 30,
#          '高點': 29,
#          '分析師': 29,
#          '逆勢': 29,
#          '日月光': 29,
#          '日線': 29,
#          '13': 29,
#          '餐旅': 29,
#          '上揚': 29,
#          '500': 29,
#          '停止': 29,
#          '大陸': 29,
#          '10.0': 29,
#          '衝上': 28,
#          '29': 28,
#          '創意': 28,
#          '樂觀': 28,
#          '世芯': 28,
#          '收復': 28,
#          '17': 28,
#          '2618': 28,
#          '易飛網': 28,
#          '25': 28,
#          '仁寶': 28,
#          '位數': 27,
#          '合併': 27,
#          '遠雄': 27,
#          '金額': 27,
#          '強勁': 27,
#          '預估': 27,
#          '編輯': 27,
#          '輝達': 27,
#          '技嘉': 27,
#          '挑戰': 27,
#          '英業達': 27,
#          '董事會': 27,
#          '決議': 27,
#          '樂事': 27,
#          '開始': 27,
#          '說明會': 27,
#          '2731': 26,
#          '集團': 26,
#          '高價': 26,
#          '重挫': 26,
#          '季線': 26,
#          '3231': 26,
#          '華碩': 26,
#          '紅盤': 26,
#          '進行': 26,
#          '科技股': 26,
#          '原文': 26,
#          '消費': 26,
#          '31': 26,
#          '出國': 26,
#          '高達': 25,
#          '此外': 25,
#          '盤中': 25,
#          '支撐': 25,
#          '由於': 25,
#          '賴清德': 25,
#          '交流': 25,
#          '2024': 25,
#          '重電': 25,
#          '道瓊': 25,
#          '投顧': 25,
#          '趨勢': 25,
#          '奇鋐': 25,
#          '機率': 25,
#          '賣出': 25,
#          '提供': 25,
#          'EPS': 25,
#          '機器人': 25,
#          '股王': 24,
#          '金融股': 24,
#          '祥碩': 24,
#          '開出': 24,
#          '附近': 24,
#          '台達電': 24,
#          '華城': 24,
#          '大跌': 24,
#          '觸及': 24,
#          '電腦': 24,
#          '壓力': 24,
#          '即將': 24,
#          '營建': 24,
#          '雖然': 24,
#          '最後': 24,
#          '股東常會': 24,
#          '年度': 24,
#          '操作': 24,
#          '第三': 24,
#          '進入': 24,
#          '認為': 24,
#          '調整': 24,
#          '呈現': 23,
#          '持有': 23,
#          '點火': 23,
#          '亞都': 23,
#          '跳空': 23,
#          '弱勢': 23,
#          '28': 23,
#          '昨日': 23,
#          '參考': 23,
#          '遊戲': 23,
#          '大選': 23,
#          '上攻': 23,
#          '跌停': 23,
#          '方式': 23,
#          '熱門': 23,
#          '回檔': 23,
#          '經濟': 23,
#          '05': 23,
#          '驗證': 23,
#          '單位': 23,
#          '第一季': 23,
#          '衰退': 23,
#          '指標': 23,
#          '亞航': 23,
#          '不會': 23,
#          '改寫': 22,
#          '50': 22,
#          '開放': 22,
#          '2月': 22,
#          '動向': 22,
#          '攻上': 22,
#          '萬海': 22,
#          '格局': 22,
#          '19': 22,
#          '國內': 22,
#          '24': 22,
#          '收漲': 22,
#          '後續': 22,
#          '3.5': 22,
#          '利率': 22,
#          '元大': 22,
#          '觀望': 22,
#          '關注': 22,
#          '收高': 22,
#          '比率': 22,
#          '走跌': 22,
#          '春節': 21,
#          '老爺知': 21,
#          '創下': 21,
#          '連續': 21,
#          '停板': 21,
#          '天價': 21,
#          '互見': 21,
#          '新台幣': 21,
#          '吸引': 21,
#          '集中': 21,
#          '2303': 21,
#          '輪動': 21,
#          '焦點股': 21,
#          '依序': 21,
#          '撐盤': 21,
#          '2382': 21,
#          '光電': 21,
#          '議案': 21,
#          '雷虎': 21,
#          '第二季': 21,
#          '損益': 21,
#          '21': 21,
#          '來自': 21,
#          '倒數': 21,
#          '善意': 21,
#          '連假': 20,
#          '挹注': 20,
#          '發布': 20,
#          '隨後': 20,
#          '之上': 20,
#          '雙鴻': 20,
#          '中央社': 20,
#          '亮眼': 20,
#          '3008': 20,
#          '汽車': 20,
#          '18': 20,
#          '延續': 20,
#          '爆量': 20,
#          '上市櫃': 20,
#          '登場': 20,
#          '2719': 20,
#          '華義': 20,
#          '2707': 20,
#          '2736': 20,
#          '左右': 20,
#          '科技': 20,
#          '走弱': 20,
#          '實體': 20,
#          '敘明': 20,
#          '資產': 20,
#          '技術面': 20,
#          '出貨': 20,
#          '復甦': 20,
#          '虧損': 20,
#          '會議': 20,
#          '處置': 20,
#          '勤誠': 20,
#          '宏碁': 20,
#          '旅宿業': 20,
#          '新天地': 19,
#          '張數': 19,
#          '跌勢': 19,
#          '信驊': 19,
#          '權值': 19,
#          '貨櫃': 19,
#          '陸續': 19,
#          '表態': 19,
#          '大量': 19,
#          '造紙': 19,
#          '服務': 19,
#          '業務': 19,
#          '除了': 19,
#          '明顯': 19,
#          '2610': 19,
#          '旅客': 19,
#          '陸客': 19,
#          '設計': 19,
#          '因此': 19,
#          '失守': 19,
#          '-KY': 19,
#          '12月': 19,
#          '選舉': 19,
#          '注意': 19,
#          '導致': 19,
#          '週一': 19,
#          '變化': 19,
#          '週三': 19,
#          '類指': 19,
#          '推動': 19,
#          '113年': 19,
#          '112年度': 19,
#          '紛紛': 18,
#          '人次': 18,
#          '預計': 18,
#          '權王': 18,
#          'Fed': 18,
#          '供應': 18,
#          '六角': 18,
#          '走強': 18,
#          '漲停板': 18,
#          '普遍': 18,
#          '漲跌幅': 18,
#          '股息': 18,
#          '加持': 18,
#          '2705': 18,
#          '面臨': 18,
#          '逐步': 18,
#          '人氣': 18,
#          'IC': 18,
#          '520': 18,
#          '200': 18,
#          '標普': 18,
#          '為主': 18,
#          '費半': 18,
#          '視訊': 18,
#          '過戶': 18,
#          '景氣': 18,
#          '帶來': 18,
#          '112年': 18,
#          '所有': 18,
#          '保證金': 18,
#          '2.5': 18,
#          '加碼': 18,
#          '可以': 18,
#          '雙雙': 18,
#          '酒店': 18,
#          '工作': 18,
#          'TOP': 18,
#          'Dcard': 18,
#          '舉辦': 17,
#          '2023': 17,
#          '年增': 17,
#          '回升': 17,
#          '貢獻': 17,
#          '累計': 17,
#          '公開': 17,
#          '暑假': 17,
#          '助攻': 17,
#          '收跌': 17,
#          '能源': 17,
#          '一度': 17,
#          '中信金': 17,
#          '方案': 17,
#          '醫療': 17,
#          '領軍': 17,
#          '欣興': 17,
#          '聯詠': 17,
#          '聚焦': 17,
#          '23': 17,
#          '攜手': 17,
#          '2745': 17,
#          '措施': 17,
#          '關係': 17,
#          '湧現': 17,
#          '休市': 17,
#          '強彈': 17,
#          '發言人': 17,
#          '漢翔': 17,
#          '後市': 17,
#          '周二': 17,
#          '下半年': 17,
#          '利益': 17,
#          '淨值': 17,
#          '顯示': 17,
#          '收入': 17,
#          '8月': 17,
#          '交易量': 17,
#          '效應': 16,
#          '解封': 16,
#          '國賓': 16,
#          '焦點': 16,
#          '華園': 16,
#          '股利': 16,
#          '疲軟': 16,
#          '疲弱': 16,
#          '幅度': 16,
#          '主管': 16,
#          '111': 16,
#          '平均': 16,
#          '客戶': 16,
#          '2743': 16,
#          '針對': 16,
#          '推出': 16,
#          '2603': 16,
#          '面板': 16,
#          '消息': 16,
#          '截至': 16,
#          '繼續': 16,
#          '如下': 16,
#          '平台': 16,
#          '財務': 16,
#          '成本': 16,
#          '跌破': 16,
#          '啟動': 16,
#          '網通': 16,
#          '第二': 16,
#          '26': 16,
#          '參加': 16,
#          '暫停': 16,
#          '半年線': 16,
#          '會計': 16,
#          '旅館': 16,
#          '股名': 16,
#          'https': 16,
#          '同期': 15,
#          '同時': 15,
#          '動能': 15,
#          '銷售': 15,
#          '40': 15,
#          '消費者': 15,
#          '籌碼': 15,
#          '周五': 15,
#          '小跌': 15,
#          '指標股': 15,
#          '發表': 15,
#          '群創': 15,
#          '價值': 15,
#          '4.5': 15,
#          '營商': 15,
#          '週邊': 15,
#          '風險': 15,
#          '大廠': 15,
#          '6669': 15,
#          '包含': 15,
#          '2609': 15,
#          '鬆綁': 15,
#          '17600': 15,
#          '現金': 15,
#          '22': 15,
#          '3661': 15,
#          '03': 15,
#          'KOSPI': 15,
#          '陸資': 15,
#          '輸入': 15,
#          '領域': 15,
#          '航太': 15,
#          'RSI': 15,
#          '結束': 15,
#          '偏多': 15,
#          '第四': 15,
#          '修正': 15,
#          '搶眼': 15,
#          '備忘錄': 15,
#          '提高': 15,
#          '電纜': 15,
#          'PC': 15,
#          '本業': 15,
#          '年底': 15,
#          '部位': 15,
#          '旅展': 15,
#          '人數': 15,
#          '就職': 15,
#          '墾丁': 15,
#          '龍巖': 15,
#          '申購': 14,
#          '2727': 14,
#          '5704': 14,
#          '天地': 14,
#          '重返': 14,
#          '收盤價': 14,
#          '0.5': 14,
#          '內需': 14,
#          '寶得利': 14,
#          '玻璃': 14,
#          '事業': 14,
#          '油電': 14,
#          '鋼鐵': 14,
#          '權息': 14,
#          '神達': 14,
#          '2734': 14,
#          '下滑': 14,
#          '取得': 14,
#          '復失': 14,
#          '布局': 14,
#          '尤其': 14,
#          '市值': 14,
#          '拉抬': 14,
#          'MoneyDJ': 14,
#          '新聞中心': 14,
#          '致和證': 14,
#          '中華民國': 14,
#          '提案': 14,
#          '董事長': 14,
#          '不錯': 14,
#          '有利': 14,
#          '計畫': 14,
#          '回落': 14,
#          '27': 14,
#          '李慧蘭': 14,
#          '33': 14,
#          '智原': 14,
#          '工業': 14,
#          '軍工股': 14,
#          '工商時報': 14,
#          '大型': 14,
#          '台灣高鐵': 14,
#          '因為': 14,
#          '國旅': 14,
#          '油價': 14,
#          'LINE Pay': 14,
#          '雷科': 14,
#          '上海': 14,
#          '基本面': 13,
#          '力旺': 13,
#          '就業': 13,
#          '成功': 13,
#          '強攻': 13,
#          '倒閉': 13,
#          '航運股': 13,
#          '儘管': 13,
#          '譜瑞': 13,
#          '長假': 13,
#          '帶量': 13,
#          '先前': 13,
#          '電機': 13,
#          '小幅': 13,
#          '衝擊': 13,
#          '再生': 13,
#          '2022年': 13,
#          '齊揚': 13,
#          '日月光投控': 13,
#          '3443': 13,
#          '新興': 13,
#          '空間': 13,
#          '殖利率': 13,
#          '日本': 13,
#          '地點': 13,
#          '台南市': 13,
#          '討論': 13,
#          '提名': 13,
#          '力道': 13,
#          '是否': 13,
#          '券商': 13,
#          '週二': 13,
#          '川湖': 13,
#          '之下': 13,
#          '結合': 13,
#          'Verbatim': 13,
#          '全新': 13,
#          '開發': 13,
#          '系統': 13,
#          '減少': 13,
#          '盤初': 13,
#          '實際': 13,
#          '退休': 13,
#          '視為': 13,
#          '波克夏': 13,
#          '解除': 12,
#          '更多': 12,
#          '連結': 12,
#          '站回': 12,
#          '進場': 12,
#          '矽力': 12,
#          '電動車': 12,
#          '值得': 12,
#          '直接': 12,
#          '轉向': 12,
#          '逼近': 12,
#          '至於': 12,
#          '首季': 12,
#          '提前': 12,
#          '速報': 12,
#          '回神': 12,
#          '32': 12,
#          '0.25': 12,
#          '營建股': 12,
#          '綜合': 12,
#          '交通部': 12,
#          '符合': 12,
#          '三雄': 12,
#          '2615': 12,
#          '1日': 12,
#          '因素': 12,
#          '智邦': 12,
#          '之後': 12,
#          '推升': 12,
#          '那斯達克': 12,
#          'DR': 12,
#          '航空股': 12,
#          '修訂': 12,
#          '承認': 12,
#          '受理': 12,
#          '投票': 12,
#          '06': 12,
#          '已經': 12,
#          'CPI': 12,
#          '重啟': 12,
#          '發生': 12,
#          '寶一': 12,
#          '台指期': 12,
#          '選股': 12,
#          '台北電': 12,
#          '3017': 12,
#          '收低': 12,
#          '雲集': 12,
#          '降低': 12,
#          '原因': 12,
#          '上半年': 12,
#          '金電': 12,
#          '2630': 12,
#          '225': 12,
#          '威秀': 12,
#          '策略': 12,
#          '進一步': 12,
#          '空單': 12,
#          '個人': 12,
#          '支付': 12,
#          '華興': 12,
#          '習近平': 12,
#          '大幅': 11,
#          '紀錄': 11,
#          '止跌': 11,
#          '掛牌': 11,
#          '電金': 11,
#          '主席': 11,
#          '上下': 11,
#          '晶圓': 11,
#          '重要': 11,
#          '買進': 11,
#          '上演': 11,
#          '娛樂': 11,
#          '衝高': 11,
#          '飆漲': 11,
#          '青睞': 11,
#          '300': 11,
#          '轉強': 11,
#          '0.48': 11,
#          'MSCI': 11,
#          '短期': 11,
#          '所幸': 11,
#          '紡織': 11,
#          '觀光署': 11,
#          '陸客團': 11,
#          '保瑞': 11,
#          '安國': 11,
#          '引發': 11,
#          '擔憂': 11,
#          '出籠': 11,
#          '調節': 11,
#          '不斷': 11,
#          '議題': 11,
#          '80': 11,
#          '抗跌': 11,
#          '光寶科': 11,
#          '經營': 11,
#          '審查': 11,
#          '決算': 11,
#          '報告書': 11,
#          '標準': 11,
#          '沒有': 11,
#          '理財': 11,
#          '意願': 11,
#          '國防': 11,
#          '正式': 11,
#          '央行': 11,
#          '上周': 11,
#          '關鍵': 11,
#          '週五': 11,
#          '比較': 11,
#          '生醫': 11,
#          '來源': 11,
#          '1成': 11,
#          '3711': 11,
#          '光碟片': 11,
#          '翁明顯': 11,
#          '影城': 11,
#          '儲存': 11,
#          '通路': 11,
#          '造成': 11,
#          '標的': 11,
#          '旗下': 11,
#          '國產': 11,
#          '期貨': 11,
#          '指期': 11,
#          '餘額': 11,
#          '相當': 11,
#          '暢旺': 11,
#          '完工': 11,
#          '新品': 11,
#          '銘旺科': 11,
#          '聲明': 11,
#          '2324': 11,
#          '慶祝': 11,
#          '人力': 11,
#          '確認': 11,
#          '颱風': 11,
#          '評論': 11,
#          '元月': 10,
#          '8940': 10,
#          '用途': 10,
#          '賣超': 10,
#          '獲得': 10,
#          '鮑爾': 10,
#          '一路': 10,
#          '友達': 10,
#          '旭隼': 10,
#          '傳出': 10,
#          '漲停價': 10,
#          '橡膠': 10,
#          '造紙股': 10,
#          '飯店股': 10,
#          '聯袂': 10,
#          '燃氣': 10,
#          '決策': 10,
#          '結果': 10,
#          '43': 10,
#          '守住': 10,
#          '達到': 10,
#          '上週': 10,
#          '迎來': 10,
#          '領漲': 10,
#          '兆豐金': 10,
#          '0.19': 10,
#          '聯合': 10,
#          '龍年': 10,
#          '多數': 10,
#          '聯手': 10,
#          '上午': 10,
#          '2712': 10,
#          '持平': 10,
#          '新建路': 10,
#          '47號': 10,
#          '輔助': 10,
#          '酬勞': 10,
#          '截止': 10,
#          '股份': 10,
#          '有限': 10,
#          '需要': 10,
#          '出口': 10,
#          '信心': 10,
#          '發酵': 10,
#          '穩定': 10,
#          '物價': 10,
#          '作帳': 10,
#          '弘塑': 10,
#          '轉賣': 10,
#          '毛利率': 10,
#          '八方': 10,
#          '3035': 10,
#          '5274': 10,
#          '回測': 10,
#          '根據': 10,
#          '方向': 10,
#          '比重': 10,
#          '了結': 10,
#          '2323': 10,
#          '單價': 10,
#          '重大': 10,
#          '餐廳': 10,
#          '29日': 10,
#          '缺口': 10,
#          '民眾': 10,
#          '庫存': 10,
#          '攻頂': 10,
#          '反映': 10,
#          '週四': 10,
#          '台電': 10,
#          '基期': 10,
#          '客運': 10,
#          ...})

# %%
df_counter_bear
# Out:
# Counter({'夏都': 189,
#          '台股': 133,
#          '觀光': 131,
#          '指數': 115,
#          '漲幅': 102,
#          '2722': 97,
#          '族群': 95,
#          '表現': 93,
#          '台積電': 91,
#          '寒舍': 91,
#          '上漲': 88,
#          '股價': 84,
#          '漲停': 84,
#          '今日': 83,
#          '市場': 79,
#          '台北': 79,
#          '雲品': 79,
#          '法人': 78,
#          'KY': 78,
#          '大漲': 77,
#          '持續': 76,
#          '類股': 76,
#          '10': 73,
#          '震盪': 71,
#          '下跌': 71,
#          '鳳凰': 67,
#          '電子': 66,
#          '加權': 66,
#          '外資': 64,
#          '記者': 64,
#          '美股': 63,
#          '股市': 63,
#          'AI': 63,
#          '終場': 62,
#          '聯發科': 61,
#          '相關': 61,
#          '雄獅': 60,
#          '今年': 60,
#          '收盤': 60,
#          '帶動': 59,
#          '台灣': 59,
#          '鴻海': 59,
#          '大盤': 58,
#          '方面': 58,
#          '表示': 57,
#          '跌幅': 57,
#          '資金': 56,
#          '成交量': 56,
#          '其中': 55,
#          '概念股': 55,
#          '加上': 54,
#          '上市': 54,
#          '公司': 54,
#          '題材': 53,
#          '報導': 53,
#          '以上': 52,
#          '國際': 52,
#          '觀光股': 51,
#          '晶華': 51,
#          '20': 50,
#          '強勢': 50,
#          '其他': 49,
#          '營收': 48,
#          '目前': 48,
#          '超過': 48,
#          '走高': 48,
#          '長榮航': 48,
#          '15': 48,
#          '聯電': 47,
#          '早盤': 47,
#          '投資': 47,
#          '個股': 46,
#          '新高': 46,
#          '開高': 46,
#          '富野': 46,
#          '半導體': 46,
#          '廣達': 46,
#          '旅遊': 45,
#          '獲利': 45,
#          '2330': 45,
#          '緯創': 45,
#          '2023年': 45,
#          '飯店': 44,
#          '投信': 44,
#          '金融': 44,
#          '預期': 43,
#          '盤面': 43,
#          '產業': 43,
#          '美國': 43,
#          '時報': 43,
#          '激勵': 41,
#          '航空': 41,
#          '11': 41,
#          '影響': 41,
#          '買超': 40,
#          '政策': 40,
#          '平盤': 40,
#          '華航': 40,
#          '2739': 40,
#          '新聞': 39,
#          '不過': 39,
#          '亮燈': 39,
#          '數據': 39,
#          '賣壓': 38,
#          '走勢': 38,
#          '開盤': 38,
#          '六福': 37,
#          '2024年': 37,
#          '受惠': 36,
#          '反彈': 36,
#          '大立光': 36,
#          '山富': 36,
#          '長榮': 36,
#          '相對': 36,
#          '商機': 36,
#          '12': 36,
#          '5月': 36,
#          '兩岸': 35,
#          '以及': 35,
#          '權值股': 35,
#          '出現': 35,
#          '包括': 35,
#          '近期': 35,
#          '王品': 34,
#          '來到': 34,
#          '走揚': 34,
#          '航運': 34,
#          '第一': 34,
#          '成長': 33,
#          '去年': 33,
#          '關卡': 33,
#          '雙雄': 33,
#          '行情': 33,
#          '恢復': 32,
#          '部分': 32,
#          '公告': 32,
#          '觀察': 32,
#          '旺季': 32,
#          '今天': 32,
#          '漲勢': 32,
#          '6月': 32,
#          '全面': 32,
#          '2748': 32,
#          '可望': 32,
#          '指出': 32,
#          '需求': 31,
#          '自營商': 31,
#          '歷史': 31,
#          '漲跌': 31,
#          '緯穎': 31,
#          '翻黑': 31,
#          '同步': 30,
#          '合計': 30,
#          '大關': 30,
#          '翻紅': 30,
#          '勁揚': 30,
#          '拖累': 30,
#          '電子股': 30,
#          '月線': 30,
#          '5706': 30,
#          '收紅': 30,
#          '政府': 29,
#          '分別': 29,
#          '隨著': 29,
#          '美食': 29,
#          '短線': 29,
#          '五福': 29,
#          '機會': 29,
#          '法說會': 29,
#          '日期': 29,
#          '證券': 29,
#          '建議': 29,
#          '16': 29,
#          '餐飲': 28,
#          '業績': 28,
#          '3月': 28,
#          '以來': 28,
#          '受到': 28,
#          '時間': 28,
#          '收在': 28,
#          '站上': 28,
#          '利多': 28,
#          '小漲': 28,
#          '2454': 28,
#          '2317': 28,
#          '財報': 28,
#          '股票': 28,
#          '陽明': 28,
#          '投控': 28,
#          '疫情': 27,
#          '公布': 27,
#          '主要': 27,
#          '營運': 27,
#          '走低': 27,
#          '投資人': 27,
#          '買盤': 27,
#          '燦星旅': 27,
#          '全球': 27,
#          '內容': 27,
#          '交易': 27,
#          '整體': 27,
#          '看好': 27,
#          '傳產': 27,
#          '產品': 27,
#          '同樣': 26,
#          '開低': 26,
#          '成交': 26,
#          '生技': 26,
#          '13': 26,
#          '可能': 26,
#          '名稱': 26,
#          '4月': 26,
#          '統計': 26,
#          '業者': 25,
#          '下挫': 25,
#          '整理': 25,
#          '再度': 25,
#          '亞洲': 25,
#          '編輯': 25,
#          '17': 25,
#          '優於': 25,
#          '融資': 25,
#          '發展': 25,
#          '概念': 25,
#          '高檔': 25,
#          '盈餘': 25,
#          '2731': 24,
#          '留意': 24,
#          '29': 24,
#          '30': 24,
#          '期間': 24,
#          '遠雄': 24,
#          '金額': 24,
#          '漲多': 24,
#          '台達電': 24,
#          '14': 24,
#          '強勁': 24,
#          '日月光': 24,
#          '日線': 24,
#          '3231': 24,
#          '2618': 24,
#          '易飛網': 24,
#          '500': 24,
#          '25': 24,
#          '召開': 24,
#          '有望': 24,
#          '企業': 23,
#          '突破': 23,
#          '另外': 23,
#          '分析師': 23,
#          '收斂': 23,
#          '創意': 23,
#          '此外': 23,
#          '強漲': 23,
#          '拉回': 23,
#          '擴大': 23,
#          '挑戰': 23,
#          '上揚': 23,
#          '股東': 23,
#          '維持': 23,
#          '積極': 23,
#          '旅行社': 22,
#          '衝上': 22,
#          '高達': 22,
#          '動向': 22,
#          '預估': 22,
#          '世芯': 22,
#          '收黑': 22,
#          '融券': 22,
#          '技嘉': 22,
#          '參考': 22,
#          '進行': 22,
#          '科技股': 22,
#          '道瓊': 22,
#          '經濟': 22,
#          '升息': 22,
#          '分析': 22,
#          '31': 22,
#          '開始': 22,
#          '增加': 21,
#          '高點': 21,
#          '2303': 21,
#          '成為': 21,
#          '萬海': 21,
#          '重挫': 21,
#          '逆勢': 21,
#          '28': 21,
#          '資訊': 21,
#          '電腦': 21,
#          '餐旅': 21,
#          '作收': 21,
#          '支撐': 21,
#          '綠能': 21,
#          '3.5': 21,
#          '雖然': 21,
#          '熱門': 21,
#          '聯準會': 21,
#          '持股': 21,
#          '奇鋐': 21,
#          '價格': 21,
#          '尾盤': 20,
#          '祥碩': 20,
#          '攻上': 20,
#          '附近': 20,
#          '亞都': 20,
#          '吸引': 20,
#          '大跌': 20,
#          '展望': 20,
#          '中央社': 20,
#          '11月': 20,
#          '汽車': 20,
#          '壓力': 20,
#          '後續': 20,
#          '未來': 20,
#          '即將': 20,
#          '2707': 20,
#          '統一': 20,
#          '宣布': 20,
#          '通膨': 20,
#          '單位': 20,
#          '多方': 20,
#          '關注': 20,
#          '均線': 20,
#          '第三': 20,
#          '認為': 20,
#          '明年': 20,
#          '來自': 20,
#          '不會': 20,
#          '老爺知': 19,
#          '股王': 19,
#          '中國': 19,
#          '集團': 19,
#          '開放': 19,
#          '2月': 19,
#          '點火': 19,
#          '高價': 19,
#          '互見': 19,
#          '新台幣': 19,
#          '盤中': 19,
#          '亮眼': 19,
#          '買賣': 19,
#          '24': 19,
#          '伺服器': 19,
#          '2719': 19,
#          '交易日': 19,
#          '2382': 19,
#          '2736': 19,
#          '重電': 19,
#          '華碩': 19,
#          'ADR': 19,
#          '利率': 19,
#          '營業': 19,
#          '觀望': 19,
#          '操作': 19,
#          '賣出': 19,
#          '勤誠': 19,
#          '新天地': 18,
#          '連續': 18,
#          '50': 18,
#          '呈現': 18,
#          '發布': 18,
#          '開出': 18,
#          '華城': 18,
#          '盤勢': 18,
#          '權值': 18,
#          '弱勢': 18,
#          '隨後': 18,
#          '普遍': 18,
#          '19': 18,
#          '上櫃': 18,
#          '漲跌幅': 18,
#          'BR': 18,
#          '輝達': 18,
#          '美元': 18,
#          '英業達': 18,
#          '登場': 18,
#          '2610': 18,
#          '由於': 18,
#          '上攻': 18,
#          '事項': 18,
#          '趨勢': 18,
#          '機率': 18,
#          '指標': 18,
#          '走跌': 18,
#          '會議': 18,
#          '創下': 17,
#          '持有': 17,
#          '跳空': 17,
#          '貨櫃': 17,
#          '格局': 17,
#          '走強': 17,
#          '釋出': 17,
#          '雙鴻': 17,
#          '表態': 17,
#          '漲停板': 17,
#          '國內': 17,
#          '觸及': 17,
#          '3008': 17,
#          '18': 17,
#          '欣興': 17,
#          '延續': 17,
#          '昨日': 17,
#          '聯詠': 17,
#          '季線': 17,
#          '明顯': 17,
#          '2745': 17,
#          '2705': 17,
#          '總統': 17,
#          '科技': 17,
#          '軍工': 17,
#          '最後': 17,
#          '走弱': 17,
#          '發言人': 17,
#          '決議': 17,
#          '05': 17,
#          '報告': 17,
#          '敘明': 17,
#          '技術面': 17,
#          '注意': 17,
#          '導致': 17,
#          '所有': 17,
#          '設備': 17,
#          '亞航': 17,
#          '復甦': 17,
#          '加碼': 17,
#          '提供': 17,
#          '2023': 16,
#          '合併': 16,
#          '累計': 16,
#          '金融股': 16,
#          '停板': 16,
#          '供應': 16,
#          '股東會': 16,
#          '一度': 16,
#          '散熱': 16,
#          '樂觀': 16,
#          '陸續': 16,
#          '放量': 16,
#          '收復': 16,
#          '2743': 16,
#          '2603': 16,
#          '2024': 16,
#          '跌停': 16,
#          '湧現': 16,
#          '停止': 16,
#          '費半': 16,
#          '回檔': 16,
#          '投顧': 16,
#          '選舉': 16,
#          '後市': 16,
#          '進入': 16,
#          'EPS': 16,
#          '訂單': 16,
#          '7月': 16,
#          '挹注': 15,
#          '回升': 15,
#          '同時': 15,
#          '公開': 15,
#          '預計': 15,
#          '助攻': 15,
#          '信驊': 15,
#          '天價': 15,
#          '收跌': 15,
#          '華園': 15,
#          '集中': 15,
#          '之上': 15,
#          '輪動': 15,
#          '造紙': 15,
#          '醫療': 15,
#          '領軍': 15,
#          '業務': 15,
#          '112': 15,
#          '面臨': 15,
#          '撐盤': 15,
#          '2609': 15,
#          '光電': 15,
#          'IC': 15,
#          '紅盤': 15,
#          '左右': 15,
#          '消息': 15,
#          '周三': 15,
#          '為主': 15,
#          '繼續': 15,
#          '-KY': 15,
#          'KOSPI': 15,
#          '陸資': 15,
#          '如下': 15,
#          '波段': 15,
#          '帶來': 15,
#          '第二': 15,
#          '提高': 15,
#          '週三': 15,
#          '下半年': 15,
#          '1月': 14,
#          '紛紛': 14,
#          '天地': 14,
#          '銷售': 14,
#          '消費者': 14,
#          '暑假': 14,
#          '籌碼': 14,
#          '權王': 14,
#          '小跌': 14,
#          '國賓': 14,
#          'Fed': 14,
#          '六角': 14,
#          '疲弱': 14,
#          '鋼鐵': 14,
#          '收漲': 14,
#          '員工': 14,
#          '平均': 14,
#          '23': 14,
#          '攜手': 14,
#          '措施': 14,
#          '布局': 14,
#          '方式': 14,
#          '因此': 14,
#          '200': 14,
#          '標普': 14,
#          '失守': 14,
#          '資料': 14,
#          '3661': 14,
#          'MoneyDJ': 14,
#          '03': 14,
#          '新聞中心': 14,
#          '驗證': 14,
#          '財務': 14,
#          '資產': 14,
#          '雷虎': 14,
#          '消費': 14,
#          '第四': 14,
#          '大型': 14,
#          '26': 14,
#          '暫停': 14,
#          '調整': 14,
#          '21': 14,
#          '顯示': 14,
#          '機器人': 14,
#          '效應': 13,
#          '2727': 13,
#          '5704': 13,
#          '解封': 13,
#          '基本面': 13,
#          '焦點': 13,
#          '群創': 13,
#          '4.5': 13,
#          '疲軟': 13,
#          '玻璃': 13,
#          '週邊': 13,
#          '中環': 13,
#          '幅度': 13,
#          '爆量': 13,
#          '上市櫃': 13,
#          '除了': 13,
#          '聚焦': 13,
#          '權息': 13,
#          '股息': 13,
#          '6669': 13,
#          '加持': 13,
#          '2734': 13,
#          '營建': 13,
#          '小幅': 13,
#          '交流': 13,
#          '人氣': 13,
#          '關係': 13,
#          '截至': 13,
#          '現金': 13,
#          '元大': 13,
#          '日月光投控': 13,
#          '12月': 13,
#          '殖利率': 13,
#          '地點': 13,
#          '輸入': 13,
#          '討論': 13,
#          '景氣': 13,
#          '啟動': 13,
#          '計畫': 13,
#          '27': 13,
#          '李慧蘭': 13,
#          '第二季': 13,
#          '比率': 13,
#          '2.5': 13,
#          '雙雙': 13,
#          '年底': 13,
#          '推動': 13,
#          '宏碁': 13,
#          '仁寶': 13,
#          '會計': 13,
#          '實際': 13,
#          '視為': 13,
#          '改寫': 12,
#          '動能': 12,
#          '113': 12,
#          '周五': 12,
#          '進場': 12,
#          '跌勢': 12,
#          '矽力': 12,
#          '指標股': 12,
#          '發表': 12,
#          '轉向': 12,
#          '航運股': 12,
#          '至於': 12,
#          '儘管': 12,
#          '大量': 12,
#          '焦點股': 12,
#          '神達': 12,
#          '逐步': 12,
#          '旅客': 12,
#          '針對': 12,
#          '推出': 12,
#          '符合': 12,
#          '三雄': 12,
#          '2615': 12,
#          '衝擊': 12,
#          '設計': 12,
#          '尤其': 12,
#          '22': 12,
#          '強彈': 12,
#          '新興': 12,
#          '空間': 12,
#          '股東常會': 12,
#          '跌破': 12,
#          '重啟': 12,
#          '領域': 12,
#          '航太': 12,
#          '董事長': 12,
#          '不錯': 12,
#          '有利': 12,
#          '台北電': 12,
#          '降低': 12,
#          '結束': 12,
#          '偏多': 12,
#          '33': 12,
#          '變化': 12,
#          '網通': 12,
#          '工業': 12,
#          '周二': 12,
#          '工商時報': 12,
#          '蘋果': 12,
#          '225': 12,
#          '大陸': 12,
#          '收入': 12,
#          '舉辦': 11,
#          '更多': 11,
#          '貢獻': 11,
#          '40': 11,
#          '收盤價': 11,
#          '力旺': 11,
#          '成功': 11,
#          '重要': 11,
#          '0.5': 11,
#          '能源': 11,
#          '中信金': 11,
#          '娛樂': 11,
#          '青睞': 11,
#          '首季': 11,
#          '提前': 11,
#          '方案': 11,
#          '內需': 11,
#          '寶得利': 11,
#          '服務': 11,
#          '事業': 11,
#          '營商': 11,
#          '油電': 11,
#          '風險': 11,
#          '大廠': 11,
#          '先前': 11,
#          '下滑': 11,
#          '大選': 11,
#          '因素': 11,
#          '智邦': 11,
#          '安國': 11,
#          '引發': 11,
#          '擔憂': 11,
#          '之後': 11,
#          '推升': 11,
#          '出籠': 11,
#          '市值': 11,
#          '那斯達克': 11,
#          '不斷': 11,
#          '議題': 11,
#          '3443': 11,
#          '日本': 11,
#          '實體': 11,
#          '召集': 11,
#          '年度': 11,
#          '成本': 11,
#          '是否': 11,
#          '理財': 11,
#          '漢翔': 11,
#          '第一季': 11,
#          '回落': 11,
#          '3017': 11,
#          '雲集': 11,
#          '關鍵': 11,
#          '週二': 11,
#          '修正': 11,
#          '原因': 11,
#          '川湖': 11,
#          '之下': 11,
#          '來源': 11,
#          '保證金': 11,
#          '3711': 11,
#          '虧損': 11,
#          '策略': 11,
#          '進一步': 11,
#          '品牌': 11,
#          '全新': 11,
#          '董事': 11,
#          '國產': 11,
#          '個人': 11,
#          '代號': 11,
#          '任何': 11,
#          '聲明': 11,
#          '確認': 11,
#          'https': 11,
#          '解除': 10,
#          '春節': 10,
#          '連假': 10,
#          '大幅': 10,
#          '年增': 10,
#          '8940': 10,
#          '用途': 10,
#          '連結': 10,
#          '站回': 10,
#          '主席': 10,
#          '電動車': 10,
#          '強攻': 10,
#          '值得': 10,
#          '價值': 10,
#          '買進': 10,
#          '直接': 10,
#          '譜瑞': 10,
#          '飆漲': 10,
#          '漲停價': 10,
#          '300': 10,
#          '轉強': 10,
#          '帶量': 10,
#          '飯店股': 10,
#          '0.48': 10,
#          '32': 10,
#          '營建股': 10,
#          '綜合': 10,
#          '電機': 10,
#          '紡織': 10,
#          '包含': 10,
#          '交通部': 10,
#          '面板': 10,
#          '1日': 10,
#          '取得': 10,
#          '陸客': 10,
#          '復失': 10,
#          '多數': 10,
#          '聯手': 10,
#          '2712': 10,
#          '原文': 10,
#          '80': 10,
#          '光寶科': 10,
#          '董事會': 10,
#          '台南市': 10,
#          '新建路': 10,
#          '47號': 10,
#          '輔助': 10,
#          '審查': 10,
#          '承認': 10,
#          '截止': 10,
#          '標準': 10,
#          'CPI': 10,
#          '發酵': 10,
#          '意願': 10,
#          '收高': 10,
#          '智原': 10,
#          '5274': 10,
#          '2630': 10,
#          '根據': 10,
#          '搶眼': 10,
#          '備忘錄': 10,
#          '造成': 10,
#          '可以': 10,
#          '旗下': 10,
#          '類指': 10,
#          '開發': 10,
#          '相當': 10,
#          '暢旺': 10,
#          '因為': 10,
#          '保證': 10,
#          '9.9': 10,
#          '標題': 10,
#          '70': 9,
#          '紀錄': 9,
#          '重返': 9,
#          '中小型股': 9,
#          '龍頭': 9,
#          '上下': 9,
#          '一路': 9,
#          '南亞科': 9,
#          '零組件': 9,
#          '逼近': 9,
#          '上演': 9,
#          '股利': 9,
#          '國泰金': 9,
#          '2.2': 9,
#          '衝高': 9,
#          '江明晏': 9,
#          '傳出': 9,
#          '造紙股': 9,
#          '華紙': 9,
#          '聯袂': 9,
#          '決策': 9,
#          '01': 9,
#          '43': 9,
#          '111': 9,
#          '守住': 9,
#          '0.25': 9,
#          '0.86': 9,
#          '客戶': 9,
#          '3324': 9,
#          '25日': 9,
#          '所幸': 9,
#          '0.19': 9,
#          '聯合': 9,
#          '再生': 9,
#          '2022年': 9,
#          '航空股': 9,
#          '抗跌': 9,
#          '成交值': 9,
#          '總計': 9,
#          '視訊': 9,
#          '事由': 9,
#          '審計': 9,
#          '委員會': 9,
#          '報告書': 9,
#          '議案': 9,
#          '臨時': 9,
#          '動議': 9,
#          '過戶': 9,
#          '起始': 9,
#          '力道': 9,
#          '信心': 9,
#          '正式': 9,
#          '作帳': 9,
#          '選股': 9,
#          '衰退': 9,
#          '率先': 9,
#          '週五': 9,
#          '八方': 9,
#          '上半年': 9,
#          '光學': 9,
#          '影線': 9,
#          '方向': 9,
#          '比重': 9,
#          '台灣高鐵': 9,
#          '2323': 9,
#          '本業': 9,
#          '毛利': 9,
#          '參加': 9,
#          '亞力': 9,
#          '攻頂': 9,
#          '指期': 9,
#          '反映': 9,
#          '系統': 9,
#          '部位': 9,
#          '基期': 9,
#          '0.05': 9,
#          '半年線': 9,
#          '訊息': 9,
#          '倒數': 9,
#          '發行': 9,
#          '順利': 9,
#          '評論': 9,
#          '⚙️   📌': 9,
#          '股名': 9,
#          '交易量': 9,
#          'TOP': 9,
#          '原樣': 9,
#          'Dcard': 9,
#          '承擔': 9,
#          '義務': 9,
#          '不宜': 9,
#          '用於': 9,
#          '稅務': 9,
#          '法務': 9,
#          '經紀人': 9,
#          '專員': 9,
#          '構成': 9,
#          '可行性': 9,
#          '適當性': 9,
#          '心得': 9,
#          '同期': 8,
#          '餐飲股': 8,
#          '35': 8,
#          '0.77': 8,
#          '銀行': 8,
#          '張數': 8,
#          '回穩': 8,
#          '逐漸': 8,
#          '瑞昱': 8,
#          '掛牌': 8,
#          '電金': 8,
#          '成交金額': 8,
#          '晶圓': 8,
#          '友達': 8,
#          'TW': 8,
#          '新光金': 8,
#          '旭隼': 8,
#          '系列': 8,
#          '有助': 8,
#          '漢來': 8,
#          '重回': 8,
#          '橡膠': 8,
#          '回神': 8,
#          '終止': 8,
#          '幾乎': 8,
#          '提醒': 8,
#          '結果': 8,
#          '34': 8,
#          '3日': 8,
#          '依序': 8,
#          '波動': 8,
#          '多頭': 8,
#          '短期': 8,
#          '達到': 8,
#          '華義': 8,
#          '期待': 8,
#          '近日': 8,
#          '農曆年': 8,
#          '迎來': 8,
#          '0.31': 8,
#          '兆豐金': 8,
#          '3481': 8,
#          '賴清德': 8,
#          '確定': 8,
#          '保瑞': 8,
#          '改變': 8,
#          '問題': 8,
#          '520': 8,
#          '1.35': 8,
#          '上午': 8,
#          '永豐金': 8,
#          '中工': 8,
#          '持平': 8,
#          '重新': 8,
#          '金寶': 8,
#          '華邦電': 8,
#          '反壓': 8,
#          '拉抬': 8,
#          '裕民': 8,
#          '鎖定': 8,
#          '研華': 8,
#          '致和證': 8,
#          '夏都城旅安平館': 8,
#          '經營': 8,
#          '酬勞': 8,
#          '平台': 8,
#          '有限': 8,
#          '08日': 8,
#          '04': 8,
#          '已經': 8,
#          '需要': 8,
#          '寶一': 8,
#          '穩定': 8,
#          '走升': 8,
#          '晨訊': 8,
#          '21日': 8,
#          '台指期': 8,
#          '壓回': 8,
#          '反觀': 8,
#          '提振': 8,
#          '樂事': 8,
#          '24日': 8,
#          '上周': 8,
#          '籌碼面': 8,
#          'RSI': 8,
#          '台玻': 8,
#          '00': 8,
#          '官員': 8,
#          '0.33': 8,
#          '上升': 8,
#          '比較': 8,
#          '3035': 8,
#          '華孚': 8,
#          '穎崴': 8,
#          '高價股': 8,
#          '出貨': 8,
#          '回測': 8,
#          '不少': 8,
#          '回歸': 8,
#          '軍工股': 8,
#          '解析': 8,
#          '0.62': 8,
#          '穩健': 8,
#          '母公司': 8,
#          '第三季': 8,
#          '5269': 8,
#          '佳世達': 8,
#          '29日': 8,
#          '缺口': 8,
#          '民眾': 8,
#          '放大': 8,
#          '團隊': 8,
#          '旅展': 8,
#          ...})

# %%
f = open('bull_tf.csv', 'w', newline='', encoding='utf-8')
writer = csv.writer(f)
for term in tf_counter_bull.most_common(200):
  writer.writerow(term)
f.close()

f = open('bear_tf.csv', 'w', newline='', encoding='utf-8')
writer = csv.writer(f)
for term in tf_counter_bear.most_common(200):
  writer.writerow(term)
f.close()

f = open('bull_df.csv', 'w', newline='', encoding='utf-8')
writer = csv.writer(f)
for term in df_counter_bull.most_common(200):
  writer.writerow(term)
f.close()

f = open('bear_df.csv', 'w', newline='', encoding='utf-8')
writer = csv.writer(f)
for term in df_counter_bear.most_common(200):
  writer.writerow(term)
f.close()

# %% [markdown]
# 以下是只有把文件資料斷詞，未篩選。作為後續訓練使用的文字集合

# %%
bull_result = list()
f = open('2722_Bull_news.csv', newline='', encoding='utf-8')
rows = csv.reader(f, delimiter=',')

i=0
for row in rows:
  i=i+1 

  if(i>1): 
    query=row[0]+' '+row[1]
    str=''
    sentence_list = utils.short_sentence(query)
    for item in sentence_list:
      result_cut = monpa.cut(item)
      for term in result_cut:
        term=term.strip()
        if(len(term)>1):
           str=str+' '+term
    print(i, str)
    bull_result.append(str)
    
f.close()
bull_result
# Out:
# 2  2023 02 15 台股 台積 重挫 大跌 221 15432 摜破 10
# 3  2023 02 22 台股 普丁 搗亂 電金 大盤 失守 月線 跌破 15400
# 4  2023 02 22 焦點股 觀光 族群 聯袂 亮燈 漲停 家數 大盤 4成
# 5  2023 02 22 美股 重挫 科技 領跌 台股 早盤 217 新聞
# 6  2023 02 23 台積電 回穩 運輸 觀光 強攻 台股 200
# 7  2023 02 23 台股 200 台積電 大漲 14
# 8  2023 03 02 速報 觀光類 指數 類股 表現 強勁 漲幅 3.9 成交額 19.90
# 9  2023 03 02 台股 早盤 40 航運 亮眼 觀光
# 10  2023 03 02 美股 收黑 台股 走低 發現 觀光股 受惠 漲停
# 11  2023 03 02 台股 民視 收盤 翻紅 專家 留意
# 12  2023 05 22 速報 夏都 2722 急跌 3.48 55.6 成交 828
# 13  2023 05 22 速報 夏都 2722 2.34 56.5 成交 1,159
# 14  2023 05 23 速報 觀光類 指數 類股 表現 強勁 漲幅 2.43 成交額 33.82億
# 15  2023 05 24 速報 夏都 2722 股價 大漲 67.7 漲幅 7.12
# 16  2023 05 24 速報 觀光類 指數 類股 表現 強勁 漲幅 2.02 成交額 10.38億
# 17  2023 05 24 速報 夏都 2722 股價 漲停 漲停價 69.5 成交 1,259
# 18  2023 05 24 台股 收盤 下跌 28.71
# 19  2023 05 24 大強 漲股 整理 台股 降溫 好事 拉回 萬六 買點
# 20  2023 06 06 台股 走揚盤 逼近 16800 觀光 族群 強勢
# 21  2023 06 06 台股 觀光 汽車 撐場 終場 小漲 47 16761.66
# 22  2023 06 13 台股 再現 電子股 狂歡 大漲 200 衝破 萬七
# 23  2023 06 19 速報 觀光類 指數 類股 表現 強勁 漲幅 2.1 成交額 3.71
# 24  2023 06 19 台股 早盤 下挫 權王 回檔 軍工 觀光 族群 閃亮
# 25  2023 06 20 台股 早盤 80 觀光 旅遊股
# 26  2023 06 27 台股 收盤 指數 跌破 16900 關卡 台積電 生技股 逆勢
# 27  2023 10 23 台股 權值 軟腳 量縮 重挫 189 16251
# 28  2023 11 06 台股 收盤 觀光 起飛 航海王 指數 16649
# 29  2023 11 07 台股 小漲 35 收復
# 30  2023 11 07 台股 收漲 35 站上 半年線 16680
# 31  2023 11 16 觀光 類股 早盤 通通 夏都 寒舍 飆漲 航空 雙雄 全面 起飛
# 32  2023 11 16 台股 甩尾 翻紅 42.4 17171.18
# 33  2023 11 16 大強 漲股 整理 財報 公布 鎖定 族群 機會 未來 表現
# 34  2023 11 22 IC 設計 14 齊衝 漲停 攜聯 發科 強守 大盤 救跌勢 台股 17310 106
# 35  2023 11 27 台股 早盤 翻黑 中國 黴漿菌 爆發 防疫 概念股 急奔 漲停
#  ' 2023 02 16 Re 哪些 低調 觀光 食品 餐廳 概念股',
#  ' 2023 03 02 新聞 缺蛋 雞蛋 概念股 沖客 大軍 集結',
#  ' 2023 04 13 新聞 雄獅 3月 營收 年增 532 漲停 領軍 觀光',
#  ' 2023 06 07 情報 2722 夏都 5月',
#  ' 2023 06 27 情報 2722 夏都 112年 5月 0.01',
#  ' 2023 07 24 情報 00733 成分股 審核 結果',
#  ' 2024 03 31 心得 2024年 台股 跌幅 排行榜',
#  ' 2024 05 28 新聞 5月 公布 兩岸 旅遊 開放 利多 觀光股',
#  ' 2024 07 22 情報 2722 夏都 辦理 現金 增資 暫定價 35',
#  ' 2024 07 22 情報 2722 夏都 投資 設立 子公司 夏都 地產 開發']

# %%
bear_result = list()
f = open('2722_Bull_news.csv', newline='', encoding='utf-8')
rows = csv.reader(f, delimiter=',')

i=0
for row in rows:
  i=i+1 

  if(i>1): 
    query=row[0]+' '+row[1]
    str=''
    sentence_list = utils.short_sentence(query)
    for item in sentence_list:
      result_cut = monpa.cut(item)
      for term in result_cut:
        term=term.strip()
        if(len(term)>1):
           str=str+' '+term
    print(i, str)
    bear_result.append(str)
    
f.close()
bear_result
# Out:
# 2  2023 02 15 台股 台積 重挫 大跌 221 15432 摜破 10
# 3  2023 02 22 台股 普丁 搗亂 電金 大盤 失守 月線 跌破 15400
# 4  2023 02 22 焦點股 觀光 族群 聯袂 亮燈 漲停 家數 大盤 4成
# 5  2023 02 22 美股 重挫 科技 領跌 台股 早盤 217 新聞
# 6  2023 02 23 台積電 回穩 運輸 觀光 強攻 台股 200
# 7  2023 02 23 台股 200 台積電 大漲 14
# 8  2023 03 02 速報 觀光類 指數 類股 表現 強勁 漲幅 3.9 成交額 19.90
# 9  2023 03 02 台股 早盤 40 航運 亮眼 觀光
# 10  2023 03 02 美股 收黑 台股 走低 發現 觀光股 受惠 漲停
# 11  2023 03 02 台股 民視 收盤 翻紅 專家 留意
# 12  2023 05 22 速報 夏都 2722 急跌 3.48 55.6 成交 828
# 13  2023 05 22 速報 夏都 2722 2.34 56.5 成交 1,159
# 14  2023 05 23 速報 觀光類 指數 類股 表現 強勁 漲幅 2.43 成交額 33.82億
# 15  2023 05 24 速報 夏都 2722 股價 大漲 67.7 漲幅 7.12
# 16  2023 05 24 速報 觀光類 指數 類股 表現 強勁 漲幅 2.02 成交額 10.38億
# 17  2023 05 24 速報 夏都 2722 股價 漲停 漲停價 69.5 成交 1,259
# 18  2023 05 24 台股 收盤 下跌 28.71
# 19  2023 05 24 大強 漲股 整理 台股 降溫 好事 拉回 萬六 買點
# 20  2023 06 06 台股 走揚盤 逼近 16800 觀光 族群 強勢
# 21  2023 06 06 台股 觀光 汽車 撐場 終場 小漲 47 16761.66
# 22  2023 06 13 台股 再現 電子股 狂歡 大漲 200 衝破 萬七
# 23  2023 06 19 速報 觀光類 指數 類股 表現 強勁 漲幅 2.1 成交額 3.71
# 24  2023 06 19 台股 早盤 下挫 權王 回檔 軍工 觀光 族群 閃亮
# 25  2023 06 20 台股 早盤 80 觀光 旅遊股
#  ' 2025 02 10 公告 夏都 2025年 1月 合併 營收 5546.5 年增 49.12',
#  ' 2025 02 17 公告 致和證 董事會 決議 召開 114年度 股東常會',
#  ' 2023 02 22 02 22 台股 收盤 指數',
#  ' 2023 02 23 02 23 台股 收盤 指數',
#  ' 2023 03 02 03 02 台股 收盤 指數',
#  ' 2023 05 23 05 23 台股 收盤 指數',
#  ' 2023 05 24 05 24 台股 收盤 指數',
#  ' 2023 06 19 06 19 台股 收盤 指數',
#  ' 2023 06 20 06 20 台股 收盤 指數',
#  ' 2023 06 20 分享 2023 06 20 股市 市場 分析',
#  ' 2023 11 06 11 06 台股 收盤 指數',
#  ' 2023 11 08 分享 11 沖空 迎廣真 噁心',
#  ' 2023 11 16 標的 焦點 個股',
#  ' 2023 11 21 分享 11 21 資金 轉移到 機殼 網通 族群 留意',
#  ' 2024 04 22 分享 焦點股',
#  ' 2024 05 28 05 28 台股 收盤 指數',
#  ' 2024 07 11 分享 0711 分享 明天',
#  ' 2023 06 15 本宮 65 夢幻 恥股 操作 心得 分享',
#  ' 2023 02 16 Re 哪些 低調 觀光 食品 餐廳 概念股',
#  ' 2023 03 02 新聞 缺蛋 雞蛋 概念股 沖客 大軍 集結',
#  ' 2023 04 13 新聞 雄獅 3月 營收 年增 532 漲停 領軍 觀光',
#  ' 2023 06 07 情報 2722 夏都 5月',
#  ' 2023 06 27 情報 2722 夏都 112年 5月 0.01',
#  ' 2023 07 24 情報 00733 成分股 審核 結果',
#  ' 2024 03 31 心得 2024年 台股 跌幅 排行榜',
#  ' 2024 05 28 新聞 5月 公布 兩岸 旅遊 開放 利多 觀光股',
#  ' 2024 07 22 情報 2722 夏都 辦理 現金 增資 暫定價 35',
#  ' 2024 07 22 情報 2722 夏都 投資 設立 子公司 夏都 地產 開發']

# %%
f = open('bull_cut_ok.csv', 'w', newline='', encoding='utf-8')
writer = csv.writer(f) 
for str in bull_result:
  writer.writerow([str])
f.close()

f = open('bear_cut_ok.csv', 'w', newline='', encoding='utf-8')
writer = csv.writer(f) 
for str in bear_result:
  writer.writerow([str])
f.close()

# %% [markdown]
# 以下是寫入個上漲與下跌詞彙，若遇到重複字就刪掉，並以此建立出有鑑別力的字集

# %%
termset_up=dict()
termset_down = dict()
no=0

f = open('bull_tf.csv', newline='', encoding='utf-8')
rows = csv.reader(f, delimiter=',')
for row in rows:
  if row[0] not in termset_up:
    termset_up[row[0]]=no
    no+=1
f.close()

f2 = open('bear_tf.csv', newline='', encoding='utf-8')
rows2 = csv.reader(f2, delimiter=',')
for row in rows2:
  if row[0] not in termset_down: 
    termset_down[row[0]]=no
    no+=1
f2.close()

# %%
print(termset_up)
# Out:
# {'指數': 0, '台股': 1, '股價': 2, '夏都': 3, '觀光': 4, '上漲': 5, '漲停': 6, '表現': 7, '漲幅': 8, '類股': 9, '族群': 10, '台積電': 11, '外資': 12, '今日': 13, '下跌': 14, '震盪': 15, '市場': 16, 'TW': 17, '2722': 18, '法人': 19, '寒舍': 20, '台北': 21, '公司': 22, '美股': 23, '跌幅': 24, 'KY': 25, '電子': 26, 'AI': 27, '終場': 28
': 231, '投資': 232, '觀光股': 233, '美股': 234, '早盤': 235, '題材': 236, '概念股': 237, '收盤': 238, '台灣': 239, '旅遊': 240, '飯店': 241, '兩岸': 242, '雲品': 243, '獲利': 244, '上市': 245, '資金': 246, '新高': 247, '加權': 248, '股市': 249, '買超': 250, '國際': 251, '鳳凰': 252, '超過': 253, '股東會': 254, '相關': 255, '產業': 256, '以上': 257, '成交量': 258, '大盤': 259, '個股': 260, '今天': 261, '帶動': 262, '其中': 263, '表示': 264, '加上': 265, '方面': 266, '雄獅': 267, '數據': 268, '強勢': 269, '鴻海': 270, '預期': 271, '長榮航': 272, '目前': 273, '走高': 274, '半導體': 275, '政策': 276, '中環': 277, '金融': 278, '記者': 279, '交易': 280, '聯發科': 281, '不過': 282, '成長': 283, '來到': 284, '投信': 285, '航空': 286, '緯創': 287, '召開': 288, '開高': 289, '20': 290, '廣達': 291, '去年': 292, '賣壓': 293, '其他': 294, '美國': 295, '事項': 296, '盤面': 297, '行情': 298, '證券': 299, '營運': 300, '激勵': 301, '走勢': 302, '15': 303, '晶華': 304, '6月': 305, '聯電': 306, '可望': 307, '翻紅': 308, '平盤': 309, 'BR': 310, '11': 311, '影響': 312, '日期': 313, '富野': 314, '報導': 315, '召集': 316, '亮燈': 317, '開盤': 318, '明年': 319, '事由': 320, '包括': 321, '華航': 322, '相對': 323, '資料': 324, '產品': 325, '受惠': 326, '2023年': 327, '恢復': 328, '同步': 329, '旺季': 330, '融券': 331, '報告': 332, '3月': 333, '月線': 334, '航運': 335, '2330': 336, '長榮': 337, '收紅': 338, '股東': 339, '7月': 340, '王品': 341, '自營商': 342, '短線': 343, '12': 344, '機會': 345, '反彈': 346, '關卡': 347, '站上': 348, '山富': 349, '第一': 350, '2024年': 351, '部分': 352, '權值股': 353, '走揚': 354, '歷史': 355, '近期': 356, '融資': 357, '股票': 358, '時報': 359, '以及': 360, '買盤': 361, '翻黑': 362, '建議': 363, '疫情': 364, '大立光': 365, '商機': 366, '員工': 367, '五福': 368, '雙雄': 369, '盈餘': 370, '9.9': 371, '需求': 372, '業績': 373, '新聞': 374, '業者': 375, '113': 376, '傳產': 377, '5月': 378, '公告': 379, '大關': 380, '觀察': 381, '漲勢': 382, '全面': 383, '財報': 384, '六福': 385, '2739': 386, '餐飲': 387, '收在': 388, '出現': 389, '勁揚': 390, '全球': 391, '漲跌': 392, '電子股': 393, '指出': 394, '公布': 395, '期間': 396, '拖累': 397, '成交': 398, '緯穎': 399}

# %%
termset_temp = dict()
num = 0

for k, v in termset_up.items():
    if k not in termset_temp:
        termset_temp[k] = num
        num+=1
    
for k, v in termset_down.items():
    if k not in termset_temp:
        termset_temp[k] = num
        num+=1
    else:
        print(f"{k} has already exist in the set")
        termset_temp.pop(k)
# Out:
# 台股 has already exist in the set
# 指數 has already exist in the set
# 觀光 has already exist in the set
# 股價 has already exist in the set
# 夏都 has already exist in the set
# 漲幅 has already exist in the set
# 上漲 has already exist in the set
# 族群 has already exist in the set
# 表現 has already exist in the set
# 漲停 has already exist in the set
# 今日 has already exist in the set
# 下跌 has already exist in the set
# 台積電 has already exist in the set
# 法人 has already exist in the set
# AI has already exist in the set
# 類股 has already exist in the set
# 公司 has already exist in the set
# 外資 has already exist in the set
# 今年 has already exist in the set
# 市場 has already exist in the set
# 持續 has already exist in the set
# KY has already exist in the set
# 營收 has already exist in the set
# 震盪 has already exist in the set
# 大漲 has already exist in the set
# 跌幅 has already exist in the set
# 台北 has already exist in the set
# 2722 has already exist in the set
# 10 has already exist in the set
# 終場 has already exist in the set
# 電子 has already exist in the set
# 寒舍 has already exist in the set
# 投資 has already exist in the set
# 觀光股 has already exist in the set
# 美股 has already exist in the set
# 早盤 has already exist in the set
# 題材 has already exist in the set
# 概念股 has already exist in the set
# 收盤 has already exist in the set
# 台灣 has already exist in the set
# 旅遊 has already exist in the set
# 飯店 has already exist in the set
# 兩岸 has already exist in the set
# 雲品 has already exist in the set
# 獲利 has already exist in the set
# 上市 has already exist in the set
# 資金 has already exist in the set
# 新高 has already exist in the set
# 加權 has already exist in the set
# 股市 has already exist in the set
# 買超 has already exist in the set
# 國際 has already exist in the set
# 鳳凰 has already exist in the set
# 超過 has already exist in the set
# 股東會 has already exist in the set
# 相關 has already exist in the set
# 產業 has already exist in the set
# 以上 has already exist in the set
# 成交量 has already exist in the set
# 大盤 has already exist in the set
# 個股 has already exist in the set
# 今天 has already exist in the set
# 帶動 has already exist in the set
# 其中 has already exist in the set
# 表示 has already exist in the set
# 加上 has already exist in the set
# 方面 has already exist in the set
# 雄獅 has already exist in the set
# 數據 has already exist in the set
# 強勢 has already exist in the set
# 鴻海 has already exist in the set
# 預期 has already exist in the set
# 長榮航 has already exist in the set
# 目前 has already exist in the set
# 走高 has already exist in the set
# 半導體 has already exist in the set
# 政策 has already exist in the set
# 金融 has already exist in the set
# 記者 has already exist in the set
# 交易 has already exist in the set
# 聯發科 has already exist in the set
# 不過 has already exist in the set
# 成長 has already exist in the set
# 來到 has already exist in the set
# 投信 has already exist in the set
# 航空 has already exist in the set
# 緯創 has already exist in the set
# 開高 has already exist in the set
# 廣達 has already exist in the set
# 去年 has already exist in the set
# 賣壓 has already exist in the set
# 其他 has already exist in the set
# 美國 has already exist in the set
# 事項 has already exist in the set
# 盤面 has already exist in the set
# 行情 has already exist in the set
# 證券 has already exist in the set
# 營運 has already exist in the set
# 激勵 has already exist in the set
# 走勢 has already exist in the set
# 晶華 has already exist in the set
# 6月 has already exist in the set
# 聯電 has already exist in the set
# 可望 has already exist in the set
# 平盤 has already exist in the set
# BR has already exist in the set
# 11 has already exist in the set
# 影響 has already exist in the set
# 日期 has already exist in the set
# 富野 has already exist in the set
# 報導 has already exist in the set
# 亮燈 has already exist in the set
# 開盤 has already exist in the set
# 包括 has already exist in the set
# 華航 has already exist in the set
# 相對 has already exist in the set
# 資料 has already exist in the set
# 受惠 has already exist in the set
# 2023年 has already exist in the set
# 同步 has already exist in the set
# 旺季 has already exist in the set
# 月線 has already exist in the set
# 航運 has already exist in the set
# 2330 has already exist in the set
# 自營商 has already exist in the set
# 短線 has already exist in the set
# 反彈 has already exist in the set
# 關卡 has already exist in the set
# 權值股 has already exist in the set
# 走揚 has already exist in the set
# 歷史 has already exist in the set
# 近期 has already exist in the set
# 時報 has already exist in the set
# 以及 has already exist in the set
# 買盤 has already exist in the set
# 翻黑 has already exist in the set
# 五福 has already exist in the set
# 雙雄 has already exist in the set
# 盈餘 has already exist in the set
# 9.9 has already exist in the set
# 需求 has already exist in the set
# 業績 has already exist in the set
# 5月 has already exist in the set
# 公告 has already exist in the set
# 漲勢 has already exist in the set
# 財報 has already exist in the set
# 六福 has already exist in the set
# 2739 has already exist in the set
# 勁揚 has already exist in the set
# 公布 has already exist in the set
# 成交 has already exist in the set

# %%
termset =dict()
num = 0
for k, v in termset_temp.items():
    if k not in termset:
        termset[k] = num
        num+=1

print(termset)
print(len(termset))
# Out:
# {'TW': 0, '金額': 1, '2454': 2, '以來': 3, '維持': 4, '資訊': 5, '發行': 6, '價格': 7, '漲多': 8, '2748': 9, '殖利率': 10, 'IC': 11, '升息': 12, '適用': 13, '開低': 14, '突破': 15, '尾盤': 16, '高點': 17, '新台幣': 18, '16': 19, '拉回': 20, '季線': 21, '合併': 22, '留意': 23, '小漲': 24, '燦星旅': 25, '累計': 26, '美元': 27, '之上': 28, '設計': 29, '走低': 30, 'EPS': 31, '整理': 32, '5706': 33, '高檔': 34, '收斂': 35, '攻上': 36, '世芯': 37, '創意': 38, '看好': 39, '均線': 40, '半年線': 41, '金融股': 42, '支撐': 43, '聯準會': 44, '23': 45, '操作': 46, '老爺知': 47, '作收': 48, '中環': 49, '召開': 50, '20': 51, '15': 52, '翻紅': 53, '召集': 54, '明年': 55, '事由': 56, '產品': 57, '恢復': 58, '融券': 59, '報告': 60, '3月': 61, '長榮': 62, '收紅': 63, '股東': 64, '7月': 65, '王品': 66, '12': 67, '機會': 68, '站上': 69, '山富': 70, '第一': 71, '2024年': 72, '部分': 73, '融資': 74, '股票': 75, '建議': 76, '疫情': 77, '大立光': 78, '商機': 79, '員工': 80, '新聞': 81, '業者': 82, '113': 83, '傳產': 84, '大關': 85, '觀察': 86, '全面': 87, '餐飲': 88, '收在': 89, '出現': 90, '全球': 91, '漲跌': 92, '電子股': 93, '指出': 94, '期間': 95, '拖累': 96, '緯穎': 97}
# 98

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

vectorizer = TfidfVectorizer(vocabulary=termset, use_idf=True, smooth_idf=True)

# %%
content=list()

f = open('bull_cut_ok.csv', newline='', encoding='utf-8')
rows = csv.reader(f, delimiter=',')
for row in rows: 
  content.append(row[0])
f.close()

f = open('bear_cut_ok.csv', newline='', encoding='utf-8') 
rows = csv.reader(f, delimiter=',')
for row in rows:
  content.append(row[0])
f.close()

print(len(content))
# Out:
# 538

# %%
X = vectorizer.fit_transform(content)
X
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:1381: UserWarning: Upper case characters found in vocabulary while 'lowercase' is True. These entries will not be matched with any documents
#   warnings.warn(
# <538x98 sparse matrix of type '<class 'numpy.float64'>'
# 	with 410 stored elements in Compressed Sparse Row format>

# %%
from scipy import sparse
sparse.save_npz('2722_model.npz', X)
